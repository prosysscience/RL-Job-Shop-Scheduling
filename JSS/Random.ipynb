# %%
import os
import multiprocessing as mp
import plotly.io as pio
import ray
from ray import tune

from JSS.CustomCallbacks import CustomCallbacks
from JSS.env.JSS import JSS
from ray.rllib.agents.ppo import ppo, PPOTrainer

from ray.tune.logger import DEFAULT_LOGGERS
from ray.tune.integration.wandb import WandbLogger

from JSS.env_wrapper import BestActionsWrapper

from JSS.models import FCMaskedActionsModel

pio.orca.config.use_xvfb = True
import wandb

'''
            'lr': {
                'values': [5e-5, 1e-5]
            },
            'lambda': {
                'values': [0.90, 0.95, 1.0]
            },
            'clip_param': {
                'values': [0.2, 0.3, 0.4]
            },
            'num_sgd_iter': {
                'values': [30, 35, 40]
            },
            'entropy_coeff': {
                'values': [0.0, 1e-4]
            }
'''

if __name__ == "__main__":
    print("I have detected {} CPUs here, so I'm going to create {} actors".format(mp.cpu_count(), mp.cpu_count() - 1))
    os.environ["WANDB_API_KEY"] = '3487a01956bf67cc7882bca2a38f70c8c95f8463'
    sweep_config = {
        'program': 'CP.py',
        'method': 'grid',
        'metric': {
            'name': 'time_step_min',
            'goal': 'minimize',
        },
        'parameters': {
            'instance_path': {
                'values': ['/JSS/JSS/env/instances/ta40', '/JSS/JSS/env/instances/ta41', '/JSS/JSS/env/instances/ta42', '/JSS/JSS/env/instances/ta43', '/JSS/JSS/env/instances/ta44',
                           '/JSS/JSS/env/instances/ta45', '/JSS/JSS/env/instances/ta46', '/JSS/JSS/env/instances/ta47', '/JSS/JSS/env/instances/ta48',
                           '/JSS/JSS/env/instances/ta49', '/JSS/JSS/env/instances/ta50']
            }
        }
    }
# Out:
# I have detected 80 CPUs here, so I'm going to create 79 actors

# %%
sweep_id = wandb.sweep(sweep_config, project="RLLIB_SWEEP_3")
# Out:
# Create sweep with ID: wnc8ihq1
# Sweep URL: https://wandb.ai/ingambe/RLLIB_SWEEP_3/sweeps/wnc8ihq1

# %%
# !wandb agent wnc8ihq1
# Out:
# wandb: Starting wandb agent 🕵️
# 2020-11-04 21:27:40,508 - wandb.wandb_agent - INFO - Running runs: []
# 2020-11-04 21:27:40,953 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-11-04 21:27:40,953 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta40
# 2020-11-04 21:27:40,955 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python CP.py --instance_path=/JSS/JSS/env/instances/ta40
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.10.8 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run CP
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_3
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_3/sweeps/wnc8ihq1
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_3/runs/h3u61381
# wandb: Run data is saved locally in wandb/run-20201104_212741-h3u61381
# wandb: Run `wandb off` to turn off syncing.
#
# 2020-11-04 21:27:45,971 - wandb.wandb_agent - INFO - Running runs: ['h3u61381']
#
# wandb: Waiting for W&B process to finish, PID 32790
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: wandb/run-20201104_212741-h3u61381/logs/debug.log
# wandb: Find internal logs for this run at: wandb/run-20201104_212741-h3u61381/logs/debug-internal.log
# wandb: Run summary:
# wandb:   best_timestep 1775.0
# wandb:           _step 0
# wandb:        _runtime 601
# wandb:      _timestamp 1604525862
# wandb: Run history:
# wandb:   best_timestep ▁
# wandb:           _step ▁
# wandb:        _runtime ▁
# wandb:      _timestamp ▁
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced CP: https://wandb.ai/ingambe/RLLIB_SWEEP_3/runs/h3u61381
# 2020-11-04 21:37:51,376 - wandb.wandb_agent - INFO - Cleaning up finished run: h3u61381
# 2020-11-04 21:37:51,696 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-11-04 21:37:51,696 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta41
# 2020-11-04 21:37:51,698 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python CP.py --instance_path=/JSS/JSS/env/instances/ta41
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.10.8 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run CP
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_3
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_3/sweeps/wnc8ihq1
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_3/runs/c18o79jq
# wandb: Run data is saved locally in wandb/run-20201104_213752-c18o79jq
# wandb: Run `wandb off` to turn off syncing.
#
# 2020-11-04 21:37:56,716 - wandb.wandb_agent - INFO - Running runs: ['c18o79jq']
#
# wandb: Waiting for W&B process to finish, PID 33712
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: wandb/run-20201104_213752-c18o79jq/logs/debug.log
# wandb: Find internal logs for this run at: wandb/run-20201104_213752-c18o79jq/logs/debug-internal.log
# wandb: Run summary:
# wandb:   best_timestep 2137.0
# wandb:           _step 0
# wandb:        _runtime 601
# wandb:      _timestamp 1604526473
# wandb: Run history:
# wandb:   best_timestep ▁
# wandb:           _step ▁
# wandb:        _runtime ▁
# wandb:      _timestamp ▁
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced CP: https://wandb.ai/ingambe/RLLIB_SWEEP_3/runs/c18o79jq
# 2020-11-04 21:48:02,339 - wandb.wandb_agent - INFO - Cleaning up finished run: c18o79jq
# 2020-11-04 21:48:02,711 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-11-04 21:48:02,712 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta42
# 2020-11-04 21:48:02,713 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python CP.py --instance_path=/JSS/JSS/env/instances/ta42
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.10.8 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run CP
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_3
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_3/sweeps/wnc8ihq1
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_3/runs/sb79yg44
# wandb: Run data is saved locally in wandb/run-20201104_214803-sb79yg44
# wandb: Run `wandb off` to turn off syncing.
#
# 2020-11-04 21:48:07,725 - wandb.wandb_agent - INFO - Running runs: ['sb79yg44']
#
# wandb: Waiting for W&B process to finish, PID 33800
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: wandb/run-20201104_214803-sb79yg44/logs/debug.log
# wandb: Find internal logs for this run at: wandb/run-20201104_214803-sb79yg44/logs/debug-internal.log
# wandb: Run summary:
# wandb:   best_timestep 2071.0
# wandb:           _step 0
# wandb:        _runtime 601
# wandb:      _timestamp 1604527084
# wandb: Run history:
# wandb:   best_timestep ▁
# wandb:           _step ▁
# wandb:        _runtime ▁
# wandb:      _timestamp ▁
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced CP: https://wandb.ai/ingambe/RLLIB_SWEEP_3/runs/sb79yg44
# 2020-11-04 21:58:08,292 - wandb.wandb_agent - INFO - Cleaning up finished run: sb79yg44
# 2020-11-04 21:58:08,653 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-11-04 21:58:08,653 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta43
# 2020-11-04 21:58:08,655 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python CP.py --instance_path=/JSS/JSS/env/instances/ta43
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.10.8 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run CP
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_3
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_3/sweeps/wnc8ihq1
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_3/runs/p3hdb6ys
# wandb: Run data is saved locally in wandb/run-20201104_215809-p3hdb6ys
# wandb: Run `wandb off` to turn off syncing.
#
# 2020-11-04 21:58:13,672 - wandb.wandb_agent - INFO - Running runs: ['p3hdb6ys']
#
# wandb: Waiting for W&B process to finish, PID 33846
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: wandb/run-20201104_215809-p3hdb6ys/logs/debug.log
# wandb: Find internal logs for this run at: wandb/run-20201104_215809-p3hdb6ys/logs/debug-internal.log
# wandb: Run summary:
# wandb:   best_timestep 1967.0
# wandb:           _step 0
# wandb:        _runtime 601
# wandb:      _timestamp 1604527690
# wandb: Run history:
# wandb:   best_timestep ▁
# wandb:           _step ▁
# wandb:        _runtime ▁
# wandb:      _timestamp ▁
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced CP: https://wandb.ai/ingambe/RLLIB_SWEEP_3/runs/p3hdb6ys
# 2020-11-04 22:08:18,999 - wandb.wandb_agent - INFO - Cleaning up finished run: p3hdb6ys
# 2020-11-04 22:08:19,334 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-11-04 22:08:19,334 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta44
# 2020-11-04 22:08:19,336 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python CP.py --instance_path=/JSS/JSS/env/instances/ta44
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.10.8 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run CP
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_3
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_3/sweeps/wnc8ihq1
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_3/runs/q6lvwcdf
# wandb: Run data is saved locally in wandb/run-20201104_220820-q6lvwcdf
# wandb: Run `wandb off` to turn off syncing.
#
# 2020-11-04 22:08:24,353 - wandb.wandb_agent - INFO - Running runs: ['q6lvwcdf']
#
# wandb: Waiting for W&B process to finish, PID 33892
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: wandb/run-20201104_220820-q6lvwcdf/logs/debug.log
# wandb: Find internal logs for this run at: wandb/run-20201104_220820-q6lvwcdf/logs/debug-internal.log
# wandb: Run summary:
# wandb:   best_timestep 2091.0
# wandb:           _step 0
# wandb:        _runtime 601
# wandb:      _timestamp 1604528301
# wandb: Run history:
# wandb:   best_timestep ▁
# wandb:           _step ▁
# wandb:        _runtime ▁
# wandb:      _timestamp ▁
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced CP: https://wandb.ai/ingambe/RLLIB_SWEEP_3/runs/q6lvwcdf
# 2020-11-04 22:18:29,584 - wandb.wandb_agent - INFO - Cleaning up finished run: q6lvwcdf
# 2020-11-04 22:18:29,915 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-11-04 22:18:29,916 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta45
# 2020-11-04 22:18:29,917 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python CP.py --instance_path=/JSS/JSS/env/instances/ta45
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.10.8 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run CP
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_3
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_3/sweeps/wnc8ihq1
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_3/runs/60frjwtk
# wandb: Run data is saved locally in wandb/run-20201104_221830-60frjwtk
# wandb: Run `wandb off` to turn off syncing.
#
# 2020-11-04 22:18:34,933 - wandb.wandb_agent - INFO - Running runs: ['60frjwtk']
#
# wandb: Waiting for W&B process to finish, PID 33938
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: wandb/run-20201104_221830-60frjwtk/logs/debug.log
# wandb: Find internal logs for this run at: wandb/run-20201104_221830-60frjwtk/logs/debug-internal.log
# wandb: Run summary:
# wandb:   best_timestep 2032.0
# wandb:           _step 0
# wandb:        _runtime 601
# wandb:      _timestamp 1604528911
# wandb: Run history:
# wandb:   best_timestep ▁
# wandb:           _step ▁
# wandb:        _runtime ▁
# wandb:      _timestamp ▁
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced CP: https://wandb.ai/ingambe/RLLIB_SWEEP_3/runs/60frjwtk
# 2020-11-04 22:28:39,901 - wandb.wandb_agent - INFO - Cleaning up finished run: 60frjwtk
# 2020-11-04 22:28:40,319 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-11-04 22:28:40,320 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta46
# 2020-11-04 22:28:40,321 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python CP.py --instance_path=/JSS/JSS/env/instances/ta46
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.10.8 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run CP
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_3
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_3/sweeps/wnc8ihq1
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_3/runs/4w63mxn5
# wandb: Run data is saved locally in wandb/run-20201104_222841-4w63mxn5
# wandb: Run `wandb off` to turn off syncing.
#
# 2020-11-04 22:28:45,337 - wandb.wandb_agent - INFO - Running runs: ['4w63mxn5']
#
# wandb: Waiting for W&B process to finish, PID 33984
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: wandb/run-20201104_222841-4w63mxn5/logs/debug.log
# wandb: Find internal logs for this run at: wandb/run-20201104_222841-4w63mxn5/logs/debug-internal.log
# wandb: Run summary:
# wandb:   best_timestep 2070.0
# wandb:           _step 0
# wandb:        _runtime 601
# wandb:      _timestamp 1604529522
# wandb: Run history:
# wandb:   best_timestep ▁
# wandb:           _step ▁
# wandb:        _runtime ▁
# wandb:      _timestamp ▁
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced CP: https://wandb.ai/ingambe/RLLIB_SWEEP_3/runs/4w63mxn5
# 2020-11-04 22:38:45,728 - wandb.wandb_agent - INFO - Cleaning up finished run: 4w63mxn5
# 2020-11-04 22:38:46,210 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-11-04 22:38:46,210 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta47
# 2020-11-04 22:38:46,212 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python CP.py --instance_path=/JSS/JSS/env/instances/ta47
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.10.8 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run CP
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_3
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_3/sweeps/wnc8ihq1
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_3/runs/qpbtop8x
# wandb: Run data is saved locally in wandb/run-20201104_223847-qpbtop8x
# wandb: Run `wandb off` to turn off syncing.
#
# 2020-11-04 22:38:51,228 - wandb.wandb_agent - INFO - Running runs: ['qpbtop8x']
#
# wandb: Waiting for W&B process to finish, PID 34030
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: wandb/run-20201104_223847-qpbtop8x/logs/debug.log
# wandb: Find internal logs for this run at: wandb/run-20201104_223847-qpbtop8x/logs/debug-internal.log
# wandb: Run summary:
# wandb:   best_timestep 1991.0
# wandb:           _step 0
# wandb:        _runtime 601
# wandb:      _timestamp 1604530128
# wandb: Run history:
# wandb:   best_timestep ▁
# wandb:           _step ▁
# wandb:        _runtime ▁
# wandb:      _timestamp ▁
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced CP: https://wandb.ai/ingambe/RLLIB_SWEEP_3/runs/qpbtop8x
# 2020-11-04 22:48:56,548 - wandb.wandb_agent - INFO - Cleaning up finished run: qpbtop8x
# 2020-11-04 22:48:56,937 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-11-04 22:48:56,937 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta48
# 2020-11-04 22:48:56,939 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python CP.py --instance_path=/JSS/JSS/env/instances/ta48
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.10.8 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run CP
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_3
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_3/sweeps/wnc8ihq1
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_3/runs/gsihk78x
# wandb: Run data is saved locally in wandb/run-20201104_224857-gsihk78x
# wandb: Run `wandb off` to turn off syncing.
#
# 2020-11-04 22:49:01,955 - wandb.wandb_agent - INFO - Running runs: ['gsihk78x']
#
# wandb: Waiting for W&B process to finish, PID 34076
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: wandb/run-20201104_224857-gsihk78x/logs/debug.log
# wandb: Find internal logs for this run at: wandb/run-20201104_224857-gsihk78x/logs/debug-internal.log
# wandb: Run summary:
# wandb:   best_timestep 2052.0
# wandb:           _step 0
# wandb:        _runtime 602
# wandb:      _timestamp 1604530739
# wandb: Run history:
# wandb:   best_timestep ▁
# wandb:           _step ▁
# wandb:        _runtime ▁
# wandb:      _timestamp ▁
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced CP: https://wandb.ai/ingambe/RLLIB_SWEEP_3/runs/gsihk78x
# 2020-11-04 22:59:07,301 - wandb.wandb_agent - INFO - Cleaning up finished run: gsihk78x
# 2020-11-04 22:59:07,606 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-11-04 22:59:07,606 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta49
# 2020-11-04 22:59:07,608 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python CP.py --instance_path=/JSS/JSS/env/instances/ta49
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.10.8 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run CP
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_3
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_3/sweeps/wnc8ihq1
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_3/runs/pvt5040k
# wandb: Run data is saved locally in wandb/run-20201104_225908-pvt5040k
# wandb: Run `wandb off` to turn off syncing.
#
# 2020-11-04 22:59:12,624 - wandb.wandb_agent - INFO - Running runs: ['pvt5040k']
#
# wandb: Waiting for W&B process to finish, PID 34122
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: wandb/run-20201104_225908-pvt5040k/logs/debug.log
# wandb: Find internal logs for this run at: wandb/run-20201104_225908-pvt5040k/logs/debug-internal.log
# wandb: Run summary:
# wandb:   best_timestep 2072.0
# wandb:           _step 0
# wandb:        _runtime 601
# wandb:      _timestamp 1604531349
# wandb: Run history:
# wandb:   best_timestep ▁
# wandb:           _step ▁
# wandb:        _runtime ▁
# wandb:      _timestamp ▁
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced CP: https://wandb.ai/ingambe/RLLIB_SWEEP_3/runs/pvt5040k
# 2020-11-04 23:09:17,980 - wandb.wandb_agent - INFO - Cleaning up finished run: pvt5040k
# 2020-11-04 23:09:18,328 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-11-04 23:09:18,328 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta50
# 2020-11-04 23:09:18,330 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python CP.py --instance_path=/JSS/JSS/env/instances/ta50
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.10.8 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run CP
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_3
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_3/sweeps/wnc8ihq1
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_3/runs/7oeiazwm
# wandb: Run data is saved locally in wandb/run-20201104_230919-7oeiazwm
# wandb: Run `wandb off` to turn off syncing.
#
# 2020-11-04 23:09:23,346 - wandb.wandb_agent - INFO - Running runs: ['7oeiazwm']
#
# wandb: Waiting for W&B process to finish, PID 34168
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: wandb/run-20201104_230919-7oeiazwm/logs/debug.log
# wandb: Find internal logs for this run at: wandb/run-20201104_230919-7oeiazwm/logs/debug-internal.log
# wandb: Run summary:
# wandb:   best_timestep 2010.0
# wandb:           _step 0
# wandb:        _runtime 601
# wandb:      _timestamp 1604531960
# wandb: Run history:
# wandb:   best_timestep ▁
# wandb:           _step ▁
# wandb:        _runtime ▁
# wandb:      _timestamp ▁
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced CP: https://wandb.ai/ingambe/RLLIB_SWEEP_3/runs/7oeiazwm
# 2020-11-04 23:19:23,596 - wandb.wandb_agent - INFO - Cleaning up finished run: 7oeiazwm
# 2020-11-04 23:19:23,944 - wandb.wandb_agent - INFO - Agent received command: exit
# 2020-11-04 23:19:23,944 - wandb.wandb_agent - INFO - Received exit command. Killing runs and quitting.
# wandb: Terminating and syncing runs. Press ctrl-c to kill.
