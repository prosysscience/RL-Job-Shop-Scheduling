# %%
import os
import multiprocessing as mp
import plotly.io as pio
import ray
from ray import tune

from JSS.CustomCallbacks import CustomCallbacks
from JSS.env.JSS import JSS
from ray.rllib.agents.ppo import ppo, PPOTrainer

from ray.tune.logger import DEFAULT_LOGGERS
from ray.tune.integration.wandb import WandbLogger

from JSS.env_wrapper import BestActionsWrapper

from JSS.models import FCMaskedActionsModel

pio.orca.config.use_xvfb = True
import wandb

'''
            'lr': {
                'values': [5e-5, 1e-5]
            },
            'lambda': {
                'values': [0.90, 0.95, 1.0]
            },
            'clip_param': {
                'values': [0.2, 0.3, 0.4]
            },
            'num_sgd_iter': {
                'values': [30, 35, 40]
            },
            'entropy_coeff': {
                'values': [0.0, 1e-4]
            }
'''

if __name__ == "__main__":
    print("I have detected {} CPUs here, so I'm going to create {} actors".format(mp.cpu_count(), mp.cpu_count() - 1))
    os.environ["WANDB_API_KEY"] = '3487a01956bf67cc7882bca2a38f70c8c95f8463'
    sweep_config = {
        'program': 'MTWR.py',
        'method': 'grid',
        'metric': {
            'name': 'time_step_min',
            'goal': 'minimize',
        },
        'parameters': {
            'instance_path': {
                'values': ['/JSS/JSS/env/instances/ta51', '/JSS/JSS/env/instances/ta52', '/JSS/JSS/env/instances/ta53', '/JSS/JSS/env/instances/ta54',
                           '/JSS/JSS/env/instances/ta55', '/JSS/JSS/env/instances/ta56', '/JSS/JSS/env/instances/ta57', '/JSS/JSS/env/instances/ta58',
                           '/JSS/JSS/env/instances/ta59', '/JSS/JSS/env/instances/ta60']
            }
        }
    }
# Out:
# I have detected 80 CPUs here, so I'm going to create 79 actors

# %%
sweep_id = wandb.sweep(sweep_config, project="RLLIB_SWEEP_2")
# Out:
# Create sweep with ID: po3ygyxo
# Sweep URL: https://wandb.ai/ingambe/RLLIB_SWEEP_2/sweeps/po3ygyxo

# %%
# !wandb agent po3ygyxo
# Out:
# wandb: Starting wandb agent 🕵️
# 2020-10-14 20:43:27,735 - wandb.wandb_agent - INFO - Running runs: []
# 2020-10-14 20:43:31,145 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-10-14 20:43:31,145 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta51
# 2020-10-14 20:43:31,147 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python MTWR.py --instance_path=/JSS/JSS/env/instances/ta51
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run MTWR
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_2
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_2/sweeps/po3ygyxo
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/9bbl2cxc
# wandb: Run data is saved locally in wandb/run-20201014_204333-9bbl2cxc
# wandb: Run `wandb off` to turn off syncing.
#
#
# wandb: Waiting for W&B process to finish, PID 3282
# wandb: Program ended successfully.
# 2020-10-14 20:43:36,159 - wandb.wandb_agent - INFO - Running runs: ['9bbl2cxc']
# wandb:
# wandb: Find user logs for this run at: wandb/run-20201014_204333-9bbl2cxc/logs/debug.log
# wandb: Find internal logs for this run at: wandb/run-20201014_204333-9bbl2cxc/logs/debug-internal.log
# wandb: Run summary:
# wandb:       nb_episodes 1
# wandb:   avg_best_result 197.38384
# wandb:      best_episode 197.38384
# wandb:     best_timestep 3753
# wandb:             _step 0
# wandb:          _runtime 1
# wandb:        _timestamp 1602708214
# wandb: Run history:
# wandb:       nb_episodes ▁
# wandb:   avg_best_result ▁
# wandb:      best_episode ▁
# wandb:     best_timestep ▁
# wandb:             _step ▁
# wandb:          _runtime ▁
# wandb:        _timestamp ▁
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced MTWR: https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/9bbl2cxc
# 2020-10-14 20:43:41,380 - wandb.wandb_agent - INFO - Cleaning up finished run: 9bbl2cxc
# 2020-10-14 20:43:41,772 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-10-14 20:43:41,772 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta52
# 2020-10-14 20:43:41,774 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python MTWR.py --instance_path=/JSS/JSS/env/instances/ta52
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run MTWR
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_2
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_2/sweeps/po3ygyxo
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/frw3hck3
# wandb: Run data is saved locally in wandb/run-20201014_204343-frw3hck3
# wandb: Run `wandb off` to turn off syncing.
#
#
# wandb: Waiting for W&B process to finish, PID 3372
# wandb: Program ended successfully.
# 2020-10-14 20:43:46,790 - wandb.wandb_agent - INFO - Running runs: ['frw3hck3']
# wandb:
# wandb: Find user logs for this run at: wandb/run-20201014_204343-frw3hck3/logs/debug.log
# wandb: Find internal logs for this run at: wandb/run-20201014_204343-frw3hck3/logs/debug-internal.log
# wandb: Run summary:
# wandb:       nb_episodes 1
# wandb:   avg_best_result 163.86869
# wandb:      best_episode 163.86869
# wandb:     best_timestep 3871
# wandb:             _step 0
# wandb:          _runtime 2
# wandb:        _timestamp 1602708225
# wandb: Run history:
# wandb:       nb_episodes ▁
# wandb:   avg_best_result ▁
# wandb:      best_episode ▁
# wandb:     best_timestep ▁
# wandb:             _step ▁
# wandb:          _runtime ▁
# wandb:        _timestamp ▁
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced MTWR: https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/frw3hck3
# 2020-10-14 20:43:52,006 - wandb.wandb_agent - INFO - Cleaning up finished run: frw3hck3
# 2020-10-14 20:43:52,326 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-10-14 20:43:52,327 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta53
# 2020-10-14 20:43:52,329 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python MTWR.py --instance_path=/JSS/JSS/env/instances/ta53
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run MTWR
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_2
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_2/sweeps/po3ygyxo
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/o0hyb863
# wandb: Run data is saved locally in wandb/run-20201014_204354-o0hyb863
# wandb: Run `wandb off` to turn off syncing.
#
#
# wandb: Waiting for W&B process to finish, PID 3461
# wandb: Program ended successfully.
# 2020-10-14 20:43:57,342 - wandb.wandb_agent - INFO - Running runs: ['o0hyb863']
# wandb:
# wandb: Find user logs for this run at: wandb/run-20201014_204354-o0hyb863/logs/debug.log
# wandb: Find internal logs for this run at: wandb/run-20201014_204354-o0hyb863/logs/debug-internal.log
# wandb: Run summary:
# wandb:       nb_episodes 1
# wandb:   avg_best_result 180.92929
# wandb:      best_episode 180.92929
# wandb:     best_timestep 3790
# wandb:             _step 0
# wandb:          _runtime 1
# wandb:        _timestamp 1602708235
# wandb: Run history:
# wandb:       nb_episodes ▁
# wandb:   avg_best_result ▁
# wandb:      best_episode ▁
# wandb:     best_timestep ▁
# wandb:             _step ▁
# wandb:          _runtime ▁
# wandb:        _timestamp ▁
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced MTWR: https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/o0hyb863
# 2020-10-14 20:44:02,563 - wandb.wandb_agent - INFO - Cleaning up finished run: o0hyb863
# 2020-10-14 20:44:02,910 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-10-14 20:44:02,911 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta54
# 2020-10-14 20:44:02,913 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python MTWR.py --instance_path=/JSS/JSS/env/instances/ta54
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run MTWR
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_2
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_2/sweeps/po3ygyxo
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/802owiob
# wandb: Run data is saved locally in wandb/run-20201014_204405-802owiob
# wandb: Run `wandb off` to turn off syncing.
#
#
# wandb: Waiting for W&B process to finish, PID 3552
# wandb: Program ended successfully.
# 2020-10-14 20:44:07,929 - wandb.wandb_agent - INFO - Running runs: ['802owiob']
# wandb:
# wandb: Find user logs for this run at: wandb/run-20201014_204405-802owiob/logs/debug.log
# wandb: Find internal logs for this run at: wandb/run-20201014_204405-802owiob/logs/debug-internal.log
# wandb: Run summary:
# wandb:       nb_episodes 1
# wandb:   avg_best_result 201.68687
# wandb:      best_episode 201.68687
# wandb:     best_timestep 3601
# wandb:             _step 0
# wandb:          _runtime 1
# wandb:        _timestamp 1602708246
# wandb: Run history:
# wandb:       nb_episodes ▁
# wandb:   avg_best_result ▁
# wandb:      best_episode ▁
# wandb:     best_timestep ▁
# wandb:             _step ▁
# wandb:          _runtime ▁
# wandb:        _timestamp ▁
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced MTWR: https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/802owiob
# 2020-10-14 20:44:13,147 - wandb.wandb_agent - INFO - Cleaning up finished run: 802owiob
# 2020-10-14 20:44:13,451 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-10-14 20:44:13,451 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta55
# 2020-10-14 20:44:13,453 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python MTWR.py --instance_path=/JSS/JSS/env/instances/ta55
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run MTWR
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_2
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_2/sweeps/po3ygyxo
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/ix8moovg
# wandb: Run data is saved locally in wandb/run-20201014_204415-ix8moovg
# wandb: Run `wandb off` to turn off syncing.
#
#
# wandb: Waiting for W&B process to finish, PID 3642
# wandb: Program ended successfully.
# 2020-10-14 20:44:18,469 - wandb.wandb_agent - INFO - Running runs: ['ix8moovg']
# wandb:
# wandb: Find user logs for this run at: wandb/run-20201014_204415-ix8moovg/logs/debug.log
# wandb: Find internal logs for this run at: wandb/run-20201014_204415-ix8moovg/logs/debug-internal.log
# wandb: Run summary:
# wandb:       nb_episodes 1
# wandb:   avg_best_result 224.37374
# wandb:      best_episode 224.37374
# wandb:     best_timestep 3435
# wandb:             _step 0
# wandb:          _runtime 1
# wandb:        _timestamp 1602708256
# wandb: Run history:
# wandb:       nb_episodes ▁
# wandb:   avg_best_result ▁
# wandb:      best_episode ▁
# wandb:     best_timestep ▁
# wandb:             _step ▁
# wandb:          _runtime ▁
# wandb:        _timestamp ▁
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced MTWR: https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/ix8moovg
# 2020-10-14 20:44:23,694 - wandb.wandb_agent - INFO - Cleaning up finished run: ix8moovg
# 2020-10-14 20:44:24,023 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-10-14 20:44:24,023 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta56
# 2020-10-14 20:44:24,025 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python MTWR.py --instance_path=/JSS/JSS/env/instances/ta56
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run MTWR
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_2
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_2/sweeps/po3ygyxo
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/zda8eskt
# wandb: Run data is saved locally in wandb/run-20201014_204426-zda8eskt
# wandb: Run `wandb off` to turn off syncing.
#
#
# wandb: Waiting for W&B process to finish, PID 3726
# wandb: Program ended successfully.
# 2020-10-14 20:44:29,037 - wandb.wandb_agent - INFO - Running runs: ['zda8eskt']
# wandb:
# wandb: Find user logs for this run at: wandb/run-20201014_204426-zda8eskt/logs/debug.log
# wandb: Find internal logs for this run at: wandb/run-20201014_204426-zda8eskt/logs/debug-internal.log
# wandb: Run summary:
# wandb:       nb_episodes 1
# wandb:   avg_best_result 178.59596
# wandb:      best_episode 178.59596
# wandb:     best_timestep 3881
# wandb:             _step 0
# wandb:          _runtime 1
# wandb:        _timestamp 1602708267
# wandb: Run history:
# wandb:       nb_episodes ▁
# wandb:   avg_best_result ▁
# wandb:      best_episode ▁
# wandb:     best_timestep ▁
# wandb:             _step ▁
# wandb:          _runtime ▁
# wandb:        _timestamp ▁
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced MTWR: https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/zda8eskt
# 2020-10-14 20:44:34,252 - wandb.wandb_agent - INFO - Cleaning up finished run: zda8eskt
# 2020-10-14 20:44:36,273 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-10-14 20:44:36,273 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta57
# 2020-10-14 20:44:36,275 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python MTWR.py --instance_path=/JSS/JSS/env/instances/ta57
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run MTWR
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_2
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_2/sweeps/po3ygyxo
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/uz9lk4hk
# wandb: Run data is saved locally in wandb/run-20201014_204438-uz9lk4hk
# wandb: Run `wandb off` to turn off syncing.
#
#
# wandb: Waiting for W&B process to finish, PID 3824
# wandb: Program ended successfully.
# 2020-10-14 20:44:41,292 - wandb.wandb_agent - INFO - Running runs: ['uz9lk4hk']
# wandb:
# wandb: Find user logs for this run at: wandb/run-20201014_204438-uz9lk4hk/logs/debug.log
# wandb: Find internal logs for this run at: wandb/run-20201014_204438-uz9lk4hk/logs/debug-internal.log
# wandb: Run summary:
# wandb:       nb_episodes 1
# wandb:   avg_best_result 209.43434
# wandb:      best_episode 209.43434
# wandb:     best_timestep 3742
# wandb:             _step 0
# wandb:          _runtime 1
# wandb:        _timestamp 1602708279
# wandb: Run history:
# wandb:       nb_episodes ▁
# wandb:   avg_best_result ▁
# wandb:      best_episode ▁
# wandb:     best_timestep ▁
# wandb:             _step ▁
# wandb:          _runtime ▁
# wandb:        _timestamp ▁
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced MTWR: https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/uz9lk4hk
# 2020-10-14 20:44:46,515 - wandb.wandb_agent - INFO - Cleaning up finished run: uz9lk4hk
# 2020-10-14 20:44:46,834 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-10-14 20:44:46,834 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta58
# 2020-10-14 20:44:46,836 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python MTWR.py --instance_path=/JSS/JSS/env/instances/ta58
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run MTWR
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_2
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_2/sweeps/po3ygyxo
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/i1pzxngg
# wandb: Run data is saved locally in wandb/run-20201014_204448-i1pzxngg
# wandb: Run `wandb off` to turn off syncing.
#
#
# wandb: Waiting for W&B process to finish, PID 3912
# wandb: Program ended successfully.
# 2020-10-14 20:44:51,849 - wandb.wandb_agent - INFO - Running runs: ['i1pzxngg']
# wandb:
# wandb: Find user logs for this run at: wandb/run-20201014_204448-i1pzxngg/logs/debug.log
# wandb: Find internal logs for this run at: wandb/run-20201014_204448-i1pzxngg/logs/debug-internal.log
# wandb: Run summary:
# wandb:       nb_episodes 1
# wandb:   avg_best_result 209.89899
# wandb:      best_episode 209.89899
# wandb:     best_timestep 3826
# wandb:             _step 0
# wandb:          _runtime 1
# wandb:        _timestamp 1602708290
# wandb: Run history:
# wandb:       nb_episodes ▁
# wandb:   avg_best_result ▁
# wandb:      best_episode ▁
# wandb:     best_timestep ▁
# wandb:             _step ▁
# wandb:          _runtime ▁
# wandb:        _timestamp ▁
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced MTWR: https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/i1pzxngg
# 2020-10-14 20:44:57,073 - wandb.wandb_agent - INFO - Cleaning up finished run: i1pzxngg
# 2020-10-14 20:44:57,383 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-10-14 20:44:57,384 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta59
# 2020-10-14 20:44:57,386 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python MTWR.py --instance_path=/JSS/JSS/env/instances/ta59
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run MTWR
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_2
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_2/sweeps/po3ygyxo
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/3kcee9dt
# wandb: Run data is saved locally in wandb/run-20201014_204459-3kcee9dt
# wandb: Run `wandb off` to turn off syncing.
#
#
# wandb: Waiting for W&B process to finish, PID 3998
# wandb: Program ended successfully.
# 2020-10-14 20:45:02,401 - wandb.wandb_agent - INFO - Running runs: ['3kcee9dt']
# wandb:
# wandb: Find user logs for this run at: wandb/run-20201014_204459-3kcee9dt/logs/debug.log
# wandb: Find internal logs for this run at: wandb/run-20201014_204459-3kcee9dt/logs/debug-internal.log
# wandb: Run summary:
# wandb:       nb_episodes 1
# wandb:   avg_best_result 211.84848
# wandb:      best_episode 211.84848
# wandb:     best_timestep 3517
# wandb:             _step 0
# wandb:          _runtime 1
# wandb:        _timestamp 1602708300
# wandb: Run history:
# wandb:       nb_episodes ▁
# wandb:   avg_best_result ▁
# wandb:      best_episode ▁
# wandb:     best_timestep ▁
# wandb:             _step ▁
# wandb:          _runtime ▁
# wandb:        _timestamp ▁
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced MTWR: https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/3kcee9dt
# 2020-10-14 20:45:07,613 - wandb.wandb_agent - INFO - Cleaning up finished run: 3kcee9dt
# 2020-10-14 20:45:10,058 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-10-14 20:45:10,059 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta60
# 2020-10-14 20:45:10,061 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python MTWR.py --instance_path=/JSS/JSS/env/instances/ta60
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run MTWR
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_2
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_2/sweeps/po3ygyxo
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/kkype8ue
# wandb: Run data is saved locally in wandb/run-20201014_204512-kkype8ue
# wandb: Run `wandb off` to turn off syncing.
#
#
# wandb: Waiting for W&B process to finish, PID 4096
# wandb: Program ended successfully.
# 2020-10-14 20:45:15,074 - wandb.wandb_agent - INFO - Running runs: ['kkype8ue']
# wandb:
# wandb: Find user logs for this run at: wandb/run-20201014_204512-kkype8ue/logs/debug.log
# wandb: Find internal logs for this run at: wandb/run-20201014_204512-kkype8ue/logs/debug-internal.log
# wandb: Run summary:
# wandb:       nb_episodes 1
# wandb:   avg_best_result 197.64646
# wandb:      best_episode 197.64646
# wandb:     best_timestep 3735
# wandb:             _step 0
# wandb:          _runtime 1
# wandb:        _timestamp 1602708313
# wandb: Run history:
# wandb:       nb_episodes ▁
# wandb:   avg_best_result ▁
# wandb:      best_episode ▁
# wandb:     best_timestep ▁
# wandb:             _step ▁
# wandb:          _runtime ▁
# wandb:        _timestamp ▁
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced MTWR: https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/kkype8ue
# 2020-10-14 20:45:20,294 - wandb.wandb_agent - INFO - Cleaning up finished run: kkype8ue
# 2020-10-14 20:45:20,607 - wandb.wandb_agent - INFO - Agent received command: exit
# 2020-10-14 20:45:20,607 - wandb.wandb_agent - INFO - Received exit command. Killing runs and quitting.
# wandb: Terminating and syncing runs. Press ctrl-c to kill.
