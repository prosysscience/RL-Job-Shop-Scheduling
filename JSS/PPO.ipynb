# %%
import os
import multiprocessing as mp
import plotly.io as pio
import ray
from ray import tune

from JSS.CustomCallbacks import CustomCallbacks
from JSS.env.JSS import JSS
from ray.rllib.agents.ppo import ppo, PPOTrainer

from ray.tune.logger import DEFAULT_LOGGERS
from ray.tune.integration.wandb import WandbLogger

from JSS.env_wrapper import BestActionsWrapper

from JSS.models import FCMaskedActionsModel

pio.orca.config.use_xvfb = True
import wandb
import torch

'''
            'lr': {
                'values': [5e-5, 1e-5]
            },
            'lambda': {
                'values': [0.90, 0.95, 1.0]
            },
            'clip_param': {
                'values': [0.2, 0.3, 0.4]
            },
            'num_sgd_iter': {
                'values': [30, 35, 40]
            },
            'entropy_coeff': {
                'values': [0.0, 1e-4]
            }
'''

if __name__ == "__main__":
    print("I have detected {} CPUs here, so I'm going to create {} actors".format(mp.cpu_count(), mp.cpu_count() - 1))
    os.environ["WANDB_API_KEY"] = '3487a01956bf67cc7882bca2a38f70c8c95f8463'
    sweep_config = {
        'program': 'train.py',
        'method': 'grid',
        'metric': {
            'name': 'time_step_min',
            'goal': 'minimize',
        },
        'parameters': {
            'lr': {
                'values': [5e-5, 1e-5]
            },
            'lambda': {
                'values': [0.90, 0.95, 1.0]
            },
            'clip_param': {
                'values': [0.2, 0.3, 0.4]
            },
            'num_sgd_iter': {
                'values': [30, 35, 40]
            },
            'entropy_coeff': {
                'values': [0.0, 1e-4]
            }
        }
    }
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-57e257253eb6> in <module>
#      14 from JSS.env_wrapper import BestActionsWrapper
#      15
# ---> 16 from JSS.models import FCMaskedActionsModel
#      17
#      18 pio.orca.config.use_xvfb = True
#
# ImportError: cannot import name 'FCMaskedActionsModel' from 'JSS.models' (/JSS/JSS/models.py)

# %%
sweep_id = wandb.sweep(sweep_config, project="RLLIB_SWEEP_4")
# Out:
# Create sweep with ID: 3vcawkyg
# Sweep URL: https://wandb.ai/ingambe/RLLIB_SWEEP_4/sweeps/3vcawkyg

# %%
# !wandb agent 3vcawkyg
# Out:
# wandb: Starting wandb agent 🕵️
# 2020-11-14 14:31:47,683 - wandb.wandb_agent - INFO - Running runs: []
# 2020-11-14 14:31:48,003 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-11-14 14:31:48,003 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta51
# 2020-11-14 14:31:48,005 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --instance_path=/JSS/JSS/env/instances/ta51
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# 2020-11-14 14:31:53,025 - wandb.wandb_agent - INFO - Running runs: ['k1k7rtin']
# wandb: Tracking run with wandb version 0.10.10
# wandb: Syncing run confused-sweep-1
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_4
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_4/sweeps/3vcawkyg
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_4/runs/k1k7rtin
# wandb: Run data is saved locally in /JSS/JSS/wandb/run-20201114_143151-k1k7rtin
# wandb: Run `wandb off` to turn off syncing.
#
# 2020-11-14 14:31:55,127	INFO services.py:1090 -- View the Ray dashboard at http://127.0.0.1:8265
# == Status ==
# Memory usage on this node: 21.1/754.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 80/80 CPUs, 1/3 GPUs, 0.0/558.15 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /root/ray_results/ppo-jss
# Number of trials: 1/1 (1 RUNNING)
# +-------------------------+----------+-------+
# | Trial name              | status   | loc   |
# |-------------------------+----------+-------|
# | PPO_jss_env_c4f5f_00000 | RUNNING  |       |
# +-------------------------+----------+-------+
#
#
# (pid=10128) 2020-11-14 14:32:01,258	INFO trainer.py:617 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=10078) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10078)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10057) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10057)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10030) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10030)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10009) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10009)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10113) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10113)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10128) 2020-11-14 14:32:13,443	INFO trainable.py:252 -- Trainable.setup took 13.029 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (pid=10130) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10130)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10106) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10106)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10064) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10064)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10118) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10118)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10053) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10053)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10108) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10108)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10050) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10050)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10089) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10089)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10098) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10098)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10115) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10115)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10101) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10101)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10052) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10052)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10051) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10051)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10105) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10105)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10061) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10061)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10059) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10059)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10066) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10066)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10016) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10016)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10119) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10119)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10076) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10076)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10111) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10111)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10069) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10069)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10046) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10046)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10125) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10125)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10120) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10120)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10122) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10122)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10048) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10048)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10043) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10043)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10023) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10023)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10018) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10018)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10062) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10062)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10093) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10093)   tensor = torch.from_numpy(np.asarray(item))
# (pid=9998) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=9998)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10024) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10024)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10054) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10054)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10058) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10058)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10055) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10055)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10022) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10022)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10025) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10025)   tensor = torch.from_numpy(np.asarray(item))
# (pid=9997) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=9997)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10007) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10007)   tensor = torch.from_numpy(np.asarray(item))
# (pid=9982) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=9982)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10020) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10020)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10028) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10028)   tensor = torch.from_numpy(np.asarray(item))
# (pid=9994) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=9994)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10084) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10084)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10029) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10029)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10040) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10040)   tensor = torch.from_numpy(np.asarray(item))
# (pid=9992) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=9992)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10012) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10012)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10073) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10073)   tensor = torch.from_numpy(np.asarray(item))
# (pid=9995) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=9995)   tensor = torch.from_numpy(np.asarray(item))
# (pid=9983) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=9983)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10026) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10026)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10015) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10015)   tensor = torch.from_numpy(np.asarray(item))
# (pid=9976) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=9976)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10033) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10033)   tensor = torch.from_numpy(np.asarray(item))
# (pid=9987) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=9987)   tensor = torch.from_numpy(np.asarray(item))
# (pid=9977) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=9977)   tensor = torch.from_numpy(np.asarray(item))
# (pid=9980) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=9980)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10014) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10014)   tensor = torch.from_numpy(np.asarray(item))
# (pid=9972) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=9972)   tensor = torch.from_numpy(np.asarray(item))
# (pid=9973) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=9973)   tensor = torch.from_numpy(np.asarray(item))
# (pid=9985) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=9985)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10021) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10021)   tensor = torch.from_numpy(np.asarray(item))
# (pid=10019) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=10019)   tensor = torch.from_numpy(np.asarray(item))
# ...
#   episode_reward_mean: 422.0138644812712
#   episode_reward_min: 376.7813230179491
#   episodes_this_iter: 178
#   episodes_total: 2212
#   experiment_id: 737438f2ca90430db994d783a4ef9c6b
#   experiment_tag: '0'
#   hostname: f85e62b52919
#   info:
#     learner:
#       default_policy:
#         allreduce_latency: 0.0
#         cur_kl_coeff: 0.20000000000000004
#         cur_lr: 5.0e-05
#         entropy: 0.9252440283695856
#         entropy_coeff: 0.0005000000000000001
#         kl: 0.009176532970741391
#         model: {}
#         policy_loss: -0.018881160494250555
#         total_loss: 11.254087368647257
#         vf_explained_var: 0.9776232838630676
#         vf_loss: 11.2715957959493
#     num_steps_sampled: 1941504
#     num_steps_trained: 1941504
#   iterations_since_restore: 12
#   node_ip: 172.17.0.14
#   num_healthy_workers: 79
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 78.56578947368419
#     gpu_util_percent0: 0.1923684210526316
#     gpu_util_percent1: 0.0
#     gpu_util_percent2: 0.8521052631578948
#     ram_util_percent: 5.4710526315789485
#     vram_util_percent0: 0.09060347654968841
#     vram_util_percent1: 0.0
#     vram_util_percent2: 0.9949178691351301
#   pid: 68673
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.20492845069318558
#     mean_env_wait_ms: 1.6859577025439765
#     mean_inference_ms: 6.359386111074373
#     mean_raw_obs_processing_ms: 0.5618482554033134
#   time_since_restore: 433.4919764995575
#   time_this_iter_s: 36.097898960113525
#   time_total_s: 433.4919764995575
#   timers:
#     learn_throughput: 6405.077
#     learn_time_ms: 25259.961
#     sample_throughput: 15687.232
#     sample_time_ms: 10313.61
#     update_time_ms: 76.907
#   timestamp: 1605365819
#   timesteps_since_restore: 0
#   timesteps_total: 1941504
#   training_iteration: 12
#   trial_id: 98ac6_00000
#
# == Status ==
# Memory usage on this node: 44.3/754.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 80/80 CPUs, 1/3 GPUs, 0.0/558.06 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /root/ray_results/ppo-jss
# Number of trials: 1/1 (1 RUNNING)
# +-------------------------+----------+-------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
# | Trial name              | status   | loc               |   iter |   total time (s) |      ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-------------------------+----------+-------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------|
# | PPO_jss_env_98ac6_00000 | RUNNING  | 172.17.0.14:68673 |     12 |          433.492 | 1941504 |  422.014 |              461.431 |              376.781 |              859.2 |
# +-------------------------+----------+-------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
#
#
# Result for PPO_jss_env_98ac6_00000:
#   custom_metrics:
#     time_step_max: 4411
#     time_step_mean: 3725.723797250859
#     time_step_min: 3348
#   date: 2020-11-14_15-57-35
#   done: false
#   episode_len_mean: 856.7345991561182
#   episode_reward_max: 461.5373230486292
#   episode_reward_mean: 422.81138755279636
#   episode_reward_min: 376.7813230179491
#   episodes_this_iter: 158
#   episodes_total: 2370
#   experiment_id: 737438f2ca90430db994d783a4ef9c6b
#   experiment_tag: '0'
#   hostname: f85e62b52919
#   info:
#     learner:
#       default_policy:
#         allreduce_latency: 0.0
#         cur_kl_coeff: 0.20000000000000004
#         cur_lr: 5.0e-05
#         entropy: 0.9096968919038773
#         entropy_coeff: 0.0005000000000000001
#         kl: 0.00963998904141287
#         model: {}
#         policy_loss: -0.019396377610974014
#         total_loss: 10.914650042851767
#         vf_explained_var: 0.9762886166572571
#         vf_loss: 10.932573000590006
#     num_steps_sampled: 2103296
#     num_steps_trained: 2103296
#   iterations_since_restore: 13
#   node_ip: 172.17.0.14
#   num_healthy_workers: 79
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 78.99999999999999
#     gpu_util_percent0: 0.16605263157894737
#     gpu_util_percent1: 0.0
#     gpu_util_percent2: 0.8539473684210527
#     ram_util_percent: 5.476315789473683
#     vram_util_percent0: 0.09060347654968841
#     vram_util_percent1: 0.0
#     vram_util_percent2: 0.9949178691351301
#   pid: 68673
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.204635852682685
#     mean_env_wait_ms: 1.6860934438534954
#     mean_inference_ms: 6.341894953892532
#     mean_raw_obs_processing_ms: 0.5609268864167443
#   time_since_restore: 469.93838715553284
#   time_this_iter_s: 36.44641065597534
#   time_total_s: 469.93838715553284
#   timers:
#     learn_throughput: 6405.072
#     learn_time_ms: 25259.982
#     sample_throughput: 15647.602
#     sample_time_ms: 10339.731
#     update_time_ms: 77.266
#   timestamp: 1605365855
#   timesteps_since_restore: 0
#   timesteps_total: 2103296
#   training_iteration: 13
#   trial_id: 98ac6_00000
#
# == Status ==
# Memory usage on this node: 43.3/754.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 80/80 CPUs, 1/3 GPUs, 0.0/558.06 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /root/ray_results/ppo-jss
# Number of trials: 1/1 (1 RUNNING)
# +-------------------------+----------+-------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
# | Trial name              | status   | loc               |   iter |   total time (s) |      ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-------------------------+----------+-------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------|
# | PPO_jss_env_98ac6_00000 | RUNNING  | 172.17.0.14:68673 |     13 |          469.938 | 2103296 |  422.811 |              461.537 |              376.781 |            856.735 |
# +-------------------------+----------+-------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
#
#
# Result for PPO_jss_env_98ac6_00000:
#   custom_metrics:
#     time_step_max: 4411
#     time_step_mean: 3721.5934861278647
#     time_step_min: 3348
#   date: 2020-11-14_15-58-12
#   done: false
#   episode_len_mean: 854.3879003558719
#   episode_reward_max: 461.5373230486292
#   episode_reward_mean: 423.4490532239591
#   episode_reward_min: 376.7813230179491
#   episodes_this_iter: 159
#   episodes_total: 2529
#   experiment_id: 737438f2ca90430db994d783a4ef9c6b
#   experiment_tag: '0'
#   hostname: f85e62b52919
#   info:
#     learner:
#       default_policy:
#         allreduce_latency: 0.0
#         cur_kl_coeff: 0.20000000000000004
#         cur_lr: 5.0e-05
#         entropy: 0.8778101652860641
#         entropy_coeff: 0.0005000000000000001
#         kl: 0.00963768681200842
#         model: {}
#         policy_loss: -0.021851512991512816
#         total_loss: 9.984525283177694
#         vf_explained_var: 0.9797164797782898
#         vf_loss: 10.00488837560018
#     num_steps_sampled: 2265088
#     num_steps_trained: 2265088
#   iterations_since_restore: 14
#   node_ip: 172.17.0.14
#   num_healthy_workers: 79
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 78.58378378378379
#     gpu_util_percent0: 0.18135135135135136
#     gpu_util_percent1: 0.0
#     gpu_util_percent2: 0.8518918918918917
#     ram_util_percent: 5.486486486486487
#     vram_util_percent0: 0.09060347654968841
#     vram_util_percent1: 0.0
#     vram_util_percent2: 0.9949178691351303
#   pid: 68673
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.20437021321773685
#     mean_env_wait_ms: 1.6863074487135563
#     mean_inference_ms: 6.325973991431816
#     mean_raw_obs_processing_ms: 0.5601003579067513
#   time_since_restore: 506.4622166156769
#   time_this_iter_s: 36.52382946014404
#   time_total_s: 506.4622166156769
#   timers:
#     learn_throughput: 6389.195
#     learn_time_ms: 25322.754
#     sample_throughput: 15584.458
#     sample_time_ms: 10381.625
#     update_time_ms: 71.837
#   timestamp: 1605365892
#   timesteps_since_restore: 0
#   timesteps_total: 2265088
#   training_iteration: 14
#   trial_id: 98ac6_00000
#
# == Status ==
# Memory usage on this node: 41.1/754.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 80/80 CPUs, 1/3 GPUs, 0.0/558.06 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /root/ray_results/ppo-jss
# Number of trials: 1/1 (1 RUNNING)
# +-------------------------+----------+-------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
# | Trial name              | status   | loc               |   iter |   total time (s) |      ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-------------------------+----------+-------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------|
# | PPO_jss_env_98ac6_00000 | RUNNING  | 172.17.0.14:68673 |     14 |          506.462 | 2265088 |  423.449 |              461.537 |              376.781 |            854.388 |
# +-------------------------+----------+-------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
#
#
# Result for PPO_jss_env_98ac6_00000:
#   custom_metrics:
#     time_step_max: 4411
#     time_step_mean: 3717.372478386167
#     time_step_min: 3348
#   date: 2020-11-14_15-58-49
#   done: false
#   episode_len_mean: 850.361958836054
#   episode_reward_max: 462.87151714792424
#   episode_reward_mean: 424.51367984471756
#   episode_reward_min: 376.7813230179491
#   episodes_this_iter: 289
#   episodes_total: 2818
#   experiment_id: 737438f2ca90430db994d783a4ef9c6b
#   experiment_tag: '0'
#   hostname: f85e62b52919
#   info:
#     learner:
#       default_policy:
#         allreduce_latency: 0.0
#         cur_kl_coeff: 0.20000000000000004
#         cur_lr: 5.0e-05
#         entropy: 0.8505634069442749
#         entropy_coeff: 0.0005000000000000001
#         kl: 0.00904827689131101
#         model: {}
#         policy_loss: -0.019613412422283243
#         total_loss: 9.04050882657369
#         vf_explained_var: 0.9870941042900085
#         vf_loss: 9.058738072713217
#     num_steps_sampled: 2426880
#     num_steps_trained: 2426880
#   iterations_since_restore: 15
#   node_ip: 172.17.0.14
#   num_healthy_workers: 79
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 78.06842105263159
#     gpu_util_percent0: 0.14947368421052634
#     gpu_util_percent1: 0.0
#     gpu_util_percent2: 0.8526315789473684
#     ram_util_percent: 5.471052631578947
#     vram_util_percent0: 0.09060347654968841
#     vram_util_percent1: 0.0
#     vram_util_percent2: 0.9949178691351301
#   pid: 68673
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.2039331695725179
#     mean_env_wait_ms: 1.68725573477544
#     mean_inference_ms: 6.300900681089996
#     mean_raw_obs_processing_ms: 0.5588149986611377
#   time_since_restore: 543.3481483459473
#   time_this_iter_s: 36.885931730270386
#   time_total_s: 543.3481483459473
#   timers:
#     learn_throughput: 6376.865
#     learn_time_ms: 25371.715
#     sample_throughput: 15509.408
#     sample_time_ms: 10431.862
#     update_time_ms: 73.015
#   timestamp: 1605365929
#   timesteps_since_restore: 0
#   timesteps_total: 2426880
#   training_iteration: 15
#   trial_id: 98ac6_00000
#
# == Status ==
# Memory usage on this node: 39.7/754.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 80/80 CPUs, 1/3 GPUs, 0.0/558.06 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /root/ray_results/ppo-jss
# Number of trials: 1/1 (1 RUNNING)
# +-------------------------+----------+-------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
# | Trial name              | status   | loc               |   iter |   total time (s) |      ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-------------------------+----------+-------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------|
# | PPO_jss_env_98ac6_00000 | RUNNING  | 172.17.0.14:68673 |     15 |          543.348 | 2426880 |  424.514 |              462.872 |              376.781 |            850.362 |
# +-------------------------+----------+-------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
#
#
# Result for PPO_jss_env_98ac6_00000:
#   custom_metrics:
#     time_step_max: 4411
#     time_step_mean: 3714.5070945945945
#     time_step_min: 3348
#   date: 2020-11-14_15-59-25
#   done: false
#   episode_len_mean: 848.2834776815456
#   episode_reward_max: 463.1137467582058
#   episode_reward_mean: 425.1674890402646
#   episode_reward_min: 376.7813230179491
#   episodes_this_iter: 184
#   episodes_total: 3002
#   experiment_id: 737438f2ca90430db994d783a4ef9c6b
#   experiment_tag: '0'
#   hostname: f85e62b52919
#   info:
#     learner:
#       default_policy:
#         allreduce_latency: 0.0
#         cur_kl_coeff: 0.20000000000000004
#         cur_lr: 5.0e-05
#         entropy: 0.8356611231962839
#         entropy_coeff: 0.0005000000000000001
#         kl: 0.008828605680416027
#         model: {}
#         policy_loss: -0.0193888185506997
#         total_loss: 8.909531116485596
#         vf_explained_var: 0.9835204482078552
#         vf_loss: 8.92757217089335
#     num_steps_sampled: 2588672
#     num_steps_trained: 2588672
#   iterations_since_restore: 16
#   node_ip: 172.17.0.14
#   num_healthy_workers: 79
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 78.03947368421053
#     gpu_util_percent0: 0.16578947368421051
#     gpu_util_percent1: 0.0
#     gpu_util_percent2: 0.7155263157894737
#     ram_util_percent: 5.478947368421053
#     vram_util_percent0: 0.09060347654968841
#     vram_util_percent1: 0.0
#     vram_util_percent2: 0.9949178691351301
#   pid: 68673
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.20369536601418672
#     mean_env_wait_ms: 1.687456378926087
#     mean_inference_ms: 6.286890510772659
#     mean_raw_obs_processing_ms: 0.5581650928138564
#   time_since_restore: 579.4591925144196
#   time_this_iter_s: 36.11104416847229
#   time_total_s: 579.4591925144196
#   timers:
#     learn_throughput: 6370.933
#     learn_time_ms: 25395.337
#     sample_throughput: 15485.682
#     sample_time_ms: 10447.845
#     update_time_ms: 54.441
#   timestamp: 1605365965
#   timesteps_since_restore: 0
#   timesteps_total: 2588672
#   training_iteration: 16
#   trial_id: 98ac6_00000
#
# == Status ==
# Memory usage on this node: 39.3/754.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 80/80 CPUs, 1/3 GPUs, 0.0/558.06 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /root/ray_results/ppo-jss
# Number of trials: 1/1 (1 RUNNING)
# +-------------------------+----------+-------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
# | Trial name              | status   | loc               |   iter |   total time (s) |      ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-------------------------+----------+-------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------|
# | PPO_jss_env_98ac6_00000 | RUNNING  | 172.17.0.14:68673 |     16 |          579.459 | 2588672 |  425.167 |              463.114 |              376.781 |            848.283 |
# +-------------------------+----------+-------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
