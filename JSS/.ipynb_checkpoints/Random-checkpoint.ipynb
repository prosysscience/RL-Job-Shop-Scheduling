# %%
import os
import multiprocessing as mp
import plotly.io as pio
import ray
from ray import tune

from JSS.CustomCallbacks import CustomCallbacks
from JSS.env.JSS import JSS
from ray.rllib.agents.ppo import ppo, PPOTrainer

from ray.tune.logger import DEFAULT_LOGGERS
from ray.tune.integration.wandb import WandbLogger

from JSS.env_wrapper import BestActionsWrapper

from JSS.models import FCMaskedActionsModel

pio.orca.config.use_xvfb = True
import wandb

'''
            'lr': {
                'values': [5e-5, 1e-5]
            },
            'lambda': {
                'values': [0.90, 0.95, 1.0]
            },
            'clip_param': {
                'values': [0.2, 0.3, 0.4]
            },
            'num_sgd_iter': {
                'values': [30, 35, 40]
            },
            'entropy_coeff': {
                'values': [0.0, 1e-4]
            }
'''

if __name__ == "__main__":
    print("I have detected {} CPUs here, so I'm going to create {} actors".format(mp.cpu_count(), mp.cpu_count() - 1))
    os.environ["WANDB_API_KEY"] = '3487a01956bf67cc7882bca2a38f70c8c95f8463'
    sweep_config = {
        'program': 'CP.py',
        'method': 'grid',
        'metric': {
            'name': 'time_step_min',
            'goal': 'minimize',
        },
        'parameters': {
            'instance_path': {
                'values': ['/JSS/JSS/env/instances/ta71', '/JSS/JSS/env/instances/ta72', '/JSS/JSS/env/instances/ta73', '/JSS/JSS/env/instances/ta74',
                           '/JSS/JSS/env/instances/ta75', '/JSS/JSS/env/instances/ta76', '/JSS/JSS/env/instances/ta77', '/JSS/JSS/env/instances/ta78',
                           '/JSS/JSS/env/instances/ta79', '/JSS/JSS/env/instances/ta80']
            }
        }
    }
# Out:
# I have detected 80 CPUs here, so I'm going to create 79 actors

# %%
sweep_id = wandb.sweep(sweep_config, project="RLLIB_SWEEP_2")
# Out:
# Create sweep with ID: kkxvg8te
# Sweep URL: https://wandb.ai/ingambe/RLLIB_SWEEP_2/sweeps/kkxvg8te

# %%
# !wandb agent kkxvg8te
# Out:
# wandb: Starting wandb agent 🕵️
# 2020-11-03 17:48:30,968 - wandb.wandb_agent - INFO - Running runs: []
# 2020-11-03 17:48:31,522 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-11-03 17:48:31,522 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta51
# 2020-11-03 17:48:31,524 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python CP.py --instance_path=/JSS/JSS/env/instances/ta51
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.10.8 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run CP
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_2
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_2/sweeps/kkxvg8te
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/quk2usr5
# wandb: Run data is saved locally in wandb/run-20201103_174832-quk2usr5
# wandb: Run `wandb off` to turn off syncing.
#
# 2020-11-03 17:48:36,541 - wandb.wandb_agent - INFO - Running runs: ['quk2usr5']
#
# wandb: Waiting for W&B process to finish, PID 24629
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: wandb/run-20201103_174832-quk2usr5/logs/debug.log
# wandb: Find internal logs for this run at: wandb/run-20201103_174832-quk2usr5/logs/debug-internal.log
# wandb: Run summary:
# wandb:   best_timestep 2762.0
# wandb:           _step 0
# wandb:        _runtime 603
# wandb:      _timestamp 1604426315
# wandb: Run history:
# wandb:   best_timestep ▁
# wandb:           _step ▁
# wandb:        _runtime ▁
# wandb:      _timestamp ▁
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced CP: https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/quk2usr5
# 2020-11-03 17:58:41,416 - wandb.wandb_agent - INFO - Cleaning up finished run: quk2usr5
# 2020-11-03 17:58:41,795 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-11-03 17:58:41,795 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta52
# 2020-11-03 17:58:41,799 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python CP.py --instance_path=/JSS/JSS/env/instances/ta52
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.10.8 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run CP
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_2
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_2/sweeps/kkxvg8te
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/l0rsmjin
# wandb: Run data is saved locally in wandb/run-20201103_175842-l0rsmjin
# wandb: Run `wandb off` to turn off syncing.
#
# 2020-11-03 17:58:46,817 - wandb.wandb_agent - INFO - Running runs: ['l0rsmjin']
#
# wandb: Waiting for W&B process to finish, PID 24731
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: wandb/run-20201103_175842-l0rsmjin/logs/debug.log
# wandb: Find internal logs for this run at: wandb/run-20201103_175842-l0rsmjin/logs/debug-internal.log
# wandb: Run summary:
# wandb:   best_timestep 2799.0
# wandb:           _step 0
# wandb:        _runtime 603
# wandb:      _timestamp 1604426925
# wandb: Run history:
# wandb:   best_timestep ▁
# wandb:           _step ▁
# wandb:        _runtime ▁
# wandb:      _timestamp ▁
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# wandb:
# wandb: Synced CP: https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/l0rsmjin
# 2020-11-03 18:08:52,752 - wandb.wandb_agent - INFO - Cleaning up finished run: l0rsmjin
# 2020-11-03 18:08:53,460 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-11-03 18:08:53,460 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta53
# 2020-11-03 18:08:53,462 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python CP.py --instance_path=/JSS/JSS/env/instances/ta53
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.10.8 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run CP
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_2
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_2/sweeps/kkxvg8te
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/dy77i2y1
# wandb: Run data is saved locally in wandb/run-20201103_180854-dy77i2y1
# wandb: Run `wandb off` to turn off syncing.
#
# 2020-11-03 18:08:58,480 - wandb.wandb_agent - INFO - Running runs: ['dy77i2y1']
