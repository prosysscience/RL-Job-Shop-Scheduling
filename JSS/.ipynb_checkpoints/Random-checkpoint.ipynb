# %%
import os
import multiprocessing as mp
import plotly.io as pio
import ray
from ray import tune

from JSS.CustomCallbacks import CustomCallbacks
from JSS.env.JSS import JSS
from ray.rllib.agents.ppo import ppo, PPOTrainer

from ray.tune.logger import DEFAULT_LOGGERS
from ray.tune.integration.wandb import WandbLogger

from JSS.env_wrapper import BestActionsWrapper

from JSS.models import FCMaskedActionsModel

pio.orca.config.use_xvfb = True
import wandb

'''
            'lr': {
                'values': [5e-5, 1e-5]
            },
            'lambda': {
                'values': [0.90, 0.95, 1.0]
            },
            'clip_param': {
                'values': [0.2, 0.3, 0.4]
            },
            'num_sgd_iter': {
                'values': [30, 35, 40]
            },
            'entropy_coeff': {
                'values': [0.0, 1e-4]
            }
'''

if __name__ == "__main__":
    print("I have detected {} CPUs here, so I'm going to create {} actors".format(mp.cpu_count(), mp.cpu_count() - 1))
    os.environ["WANDB_API_KEY"] = '3487a01956bf67cc7882bca2a38f70c8c95f8463'
    sweep_config = {
        'program': 'random_loop.py',
        'method': 'grid',
        'metric': {
            'name': 'time_step_min',
            'goal': 'minimize',
        },
        'parameters': {
            'instance_path': {
                'values': ['/JSS/JSS/env/instances/ta51', '/JSS/JSS/env/instances/ta52', '/JSS/JSS/env/instances/ta53', '/JSS/JSS/env/instances/ta54',
                           '/JSS/JSS/env/instances/ta55', '/JSS/JSS/env/instances/ta56', '/JSS/JSS/env/instances/ta57', '/JSS/JSS/env/instances/ta58',
                           '/JSS/JSS/env/instances/ta59', '/JSS/JSS/env/instances/ta60']
            }
        }
    }
# Out:
# I have detected 80 CPUs here, so I'm going to create 79 actors

# %%
sweep_id = wandb.sweep(sweep_config, project="RLLIB_SWEEP_2")
# Out:
# Create sweep with ID: kitgghxj
# Sweep URL: https://wandb.ai/ingambe/RLLIB_SWEEP_2/sweeps/kitgghxj

# %%
# !wandb agent kitgghxj
# Out:
# wandb: Starting wandb agent 🕵️
# 2020-10-13 12:32:48,579 - wandb.wandb_agent - INFO - Running runs: []
# 2020-10-13 12:32:48,906 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-10-13 12:32:48,906 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta51
# 2020-10-13 12:32:48,908 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python random_loop.py --instance_path=/JSS/JSS/env/instances/ta51
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run drawn-sweep-1
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_2
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_2/sweeps/kitgghxj
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/7zjyogzl
# wandb: Run data is saved locally in wandb/run-20201013_123250-7zjyogzl
# wandb: Run `wandb off` to turn off syncing.
#
# 2020-10-13 12:32:53,926 - wandb.wandb_agent - INFO - Running runs: ['7zjyogzl']
# 2020-10-13 12:32:54,468	INFO services.py:1164 -- View the Ray dashboard at http://127.0.0.1:8265
# == Status ==
# Memory usage on this node: 11.5/754.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 80/80 CPUs, 0/3 GPUs, 0.0/558.4 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /root/ray_results/ppo-jss
# Number of trials: 1 (1 RUNNING)
# +----------------------------------+----------+-------+
# | Trial name                       | status   | loc   |
# |----------------------------------+----------+-------|
# | RandomMasked_jss_env_3851e_00000 | RUNNING  |       |
# +----------------------------------+----------+-------+
#
#
# (pid=308) F1013 12:32:56.746781   308   308 service_based_gcs_client.cc:207] Couldn't reconnect to GCS server. The last attempted GCS server address was 172.17.0.4:35371
# (pid=308) *** Check failure stack trace: ***
# (pid=308)     @     0x7f29941c66ed  google::LogMessage::Fail()
# (pid=308)     @     0x7f29941c784c  google::LogMessage::SendToLog()
# (pid=308)     @     0x7f29941c63c9  google::LogMessage::Flush()
# (pid=308)     @     0x7f29941c65e1  google::LogMessage::~LogMessage()
# (pid=308)     @     0x7f299417d789  ray::RayLog::~RayLog()
# (pid=308)     @     0x7f2993ec11ea  ray::gcs::ServiceBasedGcsClient::ReconnectGcsServer()
# (pid=308)     @     0x7f2993ec12ef  ray::gcs::ServiceBasedGcsClient::GcsServiceFailureDetected()
# (pid=308)     @     0x7f2993ec1491  ray::gcs::ServiceBasedGcsClient::PeriodicallyCheckGcsServerAddress()
# (pid=308)     @     0x7f2993ec3801  ray::gcs::ServiceBasedGcsClient::Connect()
# (pid=318) F1013 12:32:56.731905   318   318 service_based_gcs_client.cc:207] Couldn't reconnect to GCS server. The last attempted GCS server address was 172.17.0.4:35371
# (pid=318) *** Check failure stack trace: ***
# (pid=318)     @     0x7f914d8d36ed  google::LogMessage::Fail()
# (pid=318)     @     0x7f914d8d484c  google::LogMessage::SendToLog()
# (pid=318)     @     0x7f914d8d33c9  google::LogMessage::Flush()
# (pid=318)     @     0x7f914d8d35e1  google::LogMessage::~LogMessage()
# (pid=318)     @     0x7f914d88a789  ray::RayLog::~RayLog()
# (pid=318)     @     0x7f914d5ce1ea  ray::gcs::ServiceBasedGcsClient::ReconnectGcsServer()
# (pid=318)     @     0x7f914d5ce2ef  ray::gcs::ServiceBasedGcsClient::GcsServiceFailureDetected()
# (pid=318)     @     0x7f914d5ce491  ray::gcs::ServiceBasedGcsClient::PeriodicallyCheckGcsServerAddress()
# (pid=318)     @     0x7f914d5d0801  ray::gcs::ServiceBasedGcsClient::Connect()
# (pid=318)     @     0x7f914d4df7a8  ray::gcs::GlobalStateAccessor::Connect()
# (pid=318)     @     0x7f914d450a2c  __pyx_pw_3ray_7_raylet_19GlobalStateAccessor_3connect()
# (pid=318)     @     0x55b7d9dcc98a  method_vectorcall_NOARGS
# (pid=318)     @     0x55b7d9d5cb08  _PyEval_EvalFrameDefault.cold.2792
# (pid=318)     @     0x55b7d9de76a2  _PyEval_EvalCodeWithName
# (pid=318)     @     0x55b7d9de8a20  method_vectorcall
# (pid=318)     @     0x55b7d9d5dde6  _PyEval_EvalFrameDefault.cold.2792
# (pid=318)     @     0x55b7d9de7baf  _PyEval_EvalCodeWithName
# (pid=318)     @     0x55b7d9de8643  _PyFunction_Vectorcall.localalias.353
# (pid=318)     @     0x55b7d9d5dde6  _PyEval_EvalFrameDefault.cold.2792
# (pid=318)     @     0x55b7d9de76a2  _PyEval_EvalCodeWithName
# (pid=318)     @     0x55b7d9de8454  PyEval_EvalCodeEx
# (pid=318)     @     0x55b7d9e76bbc  PyEval_EvalCode
# (pid=318)     @     0x55b7d9e76c64  run_eval_code_obj
# (pid=318)     @     0x55b7d9ea8d14  run_mod
# (pid=318)     @     0x55b7d9d71625  PyRun_FileExFlags
# (pid=318)     @     0x55b7d9d71a0a  PyRun_SimpleFileExFlags
# (pid=318)     @     0x55b7d9d728cf  Py_RunMain.cold.2911
# (pid=318)     @     0x55b7d9eab829  Py_BytesMain
# (pid=318)     @     0x7f914ebd8840  __libc_start_main
# (pid=318)     @     0x55b7d9e3bb33  (unknown)
# (pid=329) F1013 12:32:56.749399   329   329 service_based_gcs_client.cc:207] Couldn't reconnect to GCS server. The last attempted GCS server address was 172.17.0.4:35371
# (pid=329) *** Check failure stack trace: ***
# (pid=329)     @     0x7f245ddef6ed  google::LogMessage::Fail()
# (pid=329)     @     0x7f245ddf084c  google::LogMessage::SendToLog()
# (pid=329)     @     0x7f245ddef3c9  google::LogMessage::Flush()
# (pid=329)     @     0x7f245ddef5e1  google::LogMessage::~LogMessage()
# (pid=329)     @     0x7f245dda6789  ray::RayLog::~RayLog()
# (pid=329)     @     0x7f245daea1ea  ray::gcs::ServiceBasedGcsClient::ReconnectGcsServer()
# (pid=329)     @     0x7f245daea2ef  ray::gcs::ServiceBasedGcsClient::GcsServiceFailureDetected()
# (pid=329)     @     0x7f245daea491  ray::gcs::ServiceBasedGcsClient::PeriodicallyCheckGcsServerAddress()
# (pid=329)     @     0x7f245daec801  ray::gcs::ServiceBasedGcsClient::Connect()
# (pid=329)     @     0x7f245d9fb7a8  ray::gcs::GlobalStateAccessor::Connect()
# (pid=437) F1013 12:32:56.749487   437   437 service_based_gcs_client.cc:207] Couldn't reconnect to GCS server. The last attempted GCS server address was 172.17.0.4:35371
# (pid=437) *** Check failure stack trace: ***
# (pid=437)     @     0x7f92f36026ed  google::LogMessage::Fail()
# (pid=437)     @     0x7f92f360384c  google::LogMessage::SendToLog()
# (pid=437)     @     0x7f92f36023c9  google::LogMessage::Flush()
# (pid=437)     @     0x7f92f36025e1  google::LogMessage::~LogMessage()
# (pid=437)     @     0x7f92f35b9789  ray::RayLog::~RayLog()
# (pid=437)     @     0x7f92f32fd1ea  ray::gcs::ServiceBasedGcsClient::ReconnectGcsServer()
# (pid=437)     @     0x7f92f32fd2ef  ray::gcs::ServiceBasedGcsClient::GcsServiceFailureDetected()
# (pid=437)     @     0x7f92f32fd491  ray::gcs::ServiceBasedGcsClient::PeriodicallyCheckGcsServerAddress()
# (pid=437)     @     0x7f92f32ff801  ray::gcs::ServiceBasedGcsClient::Connect()
# (pid=437)     @     0x7f92f3280ed6  ray::CoreWorker::CoreWorker()
# (pid=401) F1013 12:32:56.749395   401   401 service_based_gcs_client.cc:207] Couldn't reconnect to GCS server. The last attempted GCS server address was 172.17.0.4:35371
# (pid=401) *** Check failure stack trace: ***
# (pid=401)     @     0x7f1253f536ed  google::LogMessage::Fail()
# (pid=401)     @     0x7f1253f5484c  google::LogMessage::SendToLog()
# (pid=401)     @     0x7f1253f533c9  google::LogMessage::Flush()
# (pid=401)     @     0x7f1253f535e1  google::LogMessage::~LogMessage()
# (pid=401)     @     0x7f1253f0a789  ray::RayLog::~RayLog()
# (pid=401)     @     0x7f1253c4e1ea  ray::gcs::ServiceBasedGcsClient::ReconnectGcsServer()
# (pid=401)     @     0x7f1253c4e2ef  ray::gcs::ServiceBasedGcsClient::GcsServiceFailureDetected()
# (pid=401)     @     0x7f1253c4e491  ray::gcs::ServiceBasedGcsClient::PeriodicallyCheckGcsServerAddress()
# (pid=401)     @     0x7f1253c50801  ray::gcs::ServiceBasedGcsClient::Connect()
# (pid=401)     @     0x7f1253bd1ed6  ray::CoreWorker::CoreWorker()
# (pid=363) F1013 12:32:56.749400   363   363 service_based_gcs_client.cc:207] Couldn't reconnect to GCS server. The last attempted GCS server address was 172.17.0.4:35371
# (pid=363) *** Check failure stack trace: ***
# (pid=363)     @     0x7f42549ba6ed  google::LogMessage::Fail()
# (pid=363)     @     0x7f42549bb84c  google::LogMessage::SendToLog()
# (pid=363)     @     0x7f42549ba3c9  google::LogMessage::Flush()
# (pid=363)     @     0x7f42549ba5e1  google::LogMessage::~LogMessage()
# (pid=363)     @     0x7f4254971789  ray::RayLog::~RayLog()
# (pid=363)     @     0x7f42546b51ea  ray::gcs::ServiceBasedGcsClient::ReconnectGcsServer()
# (pid=363)     @     0x7f42546b52ef  ray::gcs::ServiceBasedGcsClient::GcsServiceFailureDetected()
# (pid=363)     @     0x7f42546b5491  ray::gcs::ServiceBasedGcsClient::PeriodicallyCheckGcsServerAddress()
# (pid=363)     @     0x7f42546b7801  ray::gcs::ServiceBasedGcsClient::Connect()
# (pid=363)     @     0x7f4254638ed6  ray::CoreWorker::CoreWorker()
# (pid=308)     @     0x7f2993dd27a8  ray::gcs::GlobalStateAccessor::Connect()
# (pid=308)     @     0x7f2993d43a2c  __pyx_pw_3ray_7_raylet_19GlobalStateAccessor_3connect()
# (pid=308)     @     0x563b5c48b98a  method_vectorcall_NOARGS
# (pid=308)     @     0x563b5c41bb08  _PyEval_EvalFrameDefault.cold.2792
# (pid=308)     @     0x563b5c4a66a2  _PyEval_EvalCodeWithName
# (pid=308)     @     0x563b5c4a7a20  method_vectorcall
# (pid=308)     @     0x563b5c41cde6  _PyEval_EvalFrameDefault.cold.2792
# (pid=308)     @     0x563b5c4a6baf  _PyEval_EvalCodeWithName
# (pid=308)     @     0x563b5c4a7643  _PyFunction_Vectorcall.localalias.353
# (pid=308)     @     0x563b5c41cde6  _PyEval_EvalFrameDefault.cold.2792
# (pid=308)     @     0x563b5c4a66a2  _PyEval_EvalCodeWithName
# (pid=308)     @     0x563b5c4a7454  PyEval_EvalCodeEx
# (pid=308)     @     0x563b5c535bbc  PyEval_EvalCode
# (pid=308)     @     0x563b5c535c64  run_eval_code_obj
# (pid=308)     @     0x563b5c567d14  run_mod
# (pid=308)     @     0x563b5c430625  PyRun_FileExFlags
# (pid=308)     @     0x563b5c430a0a  PyRun_SimpleFileExFlags
# (pid=308)     @     0x563b5c4318cf  Py_RunMain.cold.2911
# (pid=308)     @     0x563b5c56a829  Py_BytesMain
# (pid=329)     @     0x7f245d96ca2c  __pyx_pw_3ray_7_raylet_19GlobalStateAccessor_3connect()
# (pid=329)     @     0x55d7f167698a  method_vectorcall_NOARGS
# (pid=329)     @     0x55d7f1606b08  _PyEval_EvalFrameDefault.cold.2792
# (pid=329)     @     0x55d7f16916a2  _PyEval_EvalCodeWithName
# (pid=329)     @     0x55d7f1692a20  method_vectorcall
# (pid=329)     @     0x55d7f1607de6  _PyEval_EvalFrameDefault.cold.2792
# (pid=329)     @     0x55d7f1691baf  _PyEval_EvalCodeWithName
# (pid=329)     @     0x55d7f1692643  _PyFunction_Vectorcall.localalias.353
# (pid=329)     @     0x55d7f1607de6  _PyEval_EvalFrameDefault.cold.2792
# (pid=329)     @     0x55d7f16916a2  _PyEval_EvalCodeWithName
# (pid=329)     @     0x55d7f1692454  PyEval_EvalCodeEx
# (pid=329)     @     0x55d7f1720bbc  PyEval_EvalCode
# (pid=329)     @     0x55d7f1720c64  run_eval_code_obj
# (pid=437)     @     0x7f92f3284c14  ray::CoreWorkerProcess::CreateWorker()
# (pid=437)     @     0x7f92f3285e82  ray::CoreWorkerProcess::CoreWorkerProcess()
# (pid=401)     @     0x7f1253bd5c14  ray::CoreWorkerProcess::CreateWorker()
# (pid=401)     @     0x7f1253bd6e82  ray::CoreWorkerProcess::CoreWorkerProcess()
# (pid=363)     @     0x7f425463cc14  ray::CoreWorkerProcess::CreateWorker()
# (pid=363)     @     0x7f425463de82  ray::CoreWorkerProcess::CoreWorkerProcess()
# (pid=308)     @     0x7f29954cb840  __libc_start_main
# (pid=308)     @     0x563b5c4fab33  (unknown)
# (pid=329)     @     0x55d7f1752d14  run_mod
# (pid=329)     @     0x55d7f161b625  PyRun_FileExFlags
# (pid=329)     @     0x55d7f161ba0a  PyRun_SimpleFileExFlags
# (pid=329)     @     0x55d7f161c8cf  Py_RunMain.cold.2911
# (pid=329)     @     0x55d7f1755829  Py_BytesMain
# (pid=329)     @     0x7f245f0f4840  __libc_start_main
# (pid=329)     @     0x55d7f16e5b33  (unknown)
# (pid=437)     @     0x7f92f328684b  ray::CoreWorkerProcess::Initialize()
# (pid=437)     @     0x7f92f31c4448  __pyx_pw_3ray_7_raylet_10CoreWorker_1__cinit__()
# (pid=437)     @     0x7f92f31c5ba5  __pyx_tp_new_3ray_7_raylet_CoreWorker()
# (pid=401)     @     0x7f1253bd784b  ray::CoreWorkerProcess::Initialize()
# (pid=401)     @     0x7f1253b15448  __pyx_pw_3ray_7_raylet_10CoreWorker_1__cinit__()
# (pid=401)     @     0x7f1253b16ba5  __pyx_tp_new_3ray_7_raylet_CoreWorker()
# (pid=363)     @     0x7f425463e84b  ray::CoreWorkerProcess::Initialize()
# (pid=363)     @     0x7f425457c448  __pyx_pw_3ray_7_raylet_10CoreWorker_1__cinit__()
# (pid=363)     @     0x7f425457dba5  __pyx_tp_new_3ray_7_raylet_CoreWorker()
# (pid=363)     @     0x5609fad7337d  _PyObject_MakeTpCall
# (pid=437)     @     0x55917d1cb37d  _PyObject_MakeTpCall
# (pid=437)     @     0x55917d253d09  _PyEval_EvalFrameDefault
# (pid=437)     @     0x55917d218baf  _PyEval_EvalCodeWithName
# (pid=437)     @     0x55917d219643  _PyFunction_Vectorcall.localalias.353
# (pid=437)     @     0x55917d18ede6  _PyEval_EvalFrameDefault.cold.2792
# (pid=437)     @     0x55917d2186a2  _PyEval_EvalCodeWithName
# (pid=437)     @     0x55917d219454  PyEval_EvalCodeEx
# (pid=437)     @     0x55917d2a7bbc  PyEval_EvalCode
# (pid=437)     @     0x55917d2a7c64  run_eval_code_obj
# (pid=437)     @     0x55917d2d9d14  run_mod
# (pid=437)     @     0x55917d1a2625  PyRun_FileExFlags
# (pid=437)     @     0x55917d1a2a0a  PyRun_SimpleFileExFlags
# (pid=401)     @     0x55c7f801b37d  _PyObject_MakeTpCall
# (pid=401)     @     0x55c7f80a3d09  _PyEval_EvalFrameDefault
# (pid=401)     @     0x55c7f8068baf  _PyEval_EvalCodeWithName
# (pid=401)     @     0x55c7f8069643  _PyFunction_Vectorcall.localalias.353
# (pid=401)     @     0x55c7f7fdede6  _PyEval_EvalFrameDefault.cold.2792
# (pid=401)     @     0x55c7f80686a2  _PyEval_EvalCodeWithName
# (pid=401)     @     0x55c7f8069454  PyEval_EvalCodeEx
# (pid=401)     @     0x55c7f80f7bbc  PyEval_EvalCode
# (pid=401)     @     0x55c7f80f7c64  run_eval_code_obj
# (pid=401)     @     0x55c7f8129d14  run_mod
# (pid=401)     @     0x55c7f7ff2625  PyRun_FileExFlags
# (pid=401)     @     0x55c7f7ff2a0a  PyRun_SimpleFileExFlags
# (pid=363)     @     0x5609fadfbd09  _PyEval_EvalFrameDefault
# (pid=363)     @     0x5609fadc0baf  _PyEval_EvalCodeWithName
# (pid=363)     @     0x5609fadc1643  _PyFunction_Vectorcall.localalias.353
# (pid=363)     @     0x5609fad36de6  _PyEval_EvalFrameDefault.cold.2792
# (pid=363)     @     0x5609fadc06a2  _PyEval_EvalCodeWithName
# (pid=363)     @     0x5609fadc1454  PyEval_EvalCodeEx
# (pid=363)     @     0x5609fae4fbbc  PyEval_EvalCode
# (pid=363)     @     0x5609fae4fc64  run_eval_code_obj
# (pid=363)     @     0x5609fae81d14  run_mod
# (pid=363)     @     0x5609fad4a625  PyRun_FileExFlags
# (pid=363)     @     0x5609fad4aa0a  PyRun_SimpleFileExFlags
# (pid=363)     @     0x5609fad4b8cf  Py_RunMain.cold.2911
# (pid=437)     @     0x55917d1a38cf  Py_RunMain.cold.2911
# (pid=437)     @     0x55917d2dc829  Py_BytesMain
# (pid=437)     @     0x7f92f4907840  __libc_start_main
# (pid=437)     @     0x55917d26cb33  (unknown)
# (pid=401)     @     0x55c7f7ff38cf  Py_RunMain.cold.2911
# (pid=401)     @     0x55c7f812c829  Py_BytesMain
# (pid=401)     @     0x7f1255258840  __libc_start_main
# (pid=401)     @     0x55c7f80bcb33  (unknown)
# (pid=363)     @     0x5609fae84829  Py_BytesMain
# (pid=363)     @     0x7f4255cbf840  __libc_start_main
# (pid=363)     @     0x5609fae14b33  (unknown)
# 2020-10-13 12:32:56,926	WARNING worker.py:1072 -- A worker died or was killed while executing task ffffffffffffffffdf5a1a8201000000.
# (pid=raylet) E1013 12:32:56.915767   265   265 node_manager.cc:3307] Failed to send get core worker stats request: IOError: 14: Socket closed
# (pid=raylet) E1013 12:32:56.929625   265   265 node_manager.cc:3307] Failed to send get core worker stats request: IOError: 14: Socket closed
# (pid=raylet) E1013 12:32:56.932425   265   265 node_manager.cc:3307] Failed to send get core worker stats request: IOError: 14: Socket closed
