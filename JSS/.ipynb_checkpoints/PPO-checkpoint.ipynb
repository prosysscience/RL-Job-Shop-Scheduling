# %%
import os
import multiprocessing as mp
import plotly.io as pio
import ray
from ray import tune

from JSS.CustomCallbacks import CustomCallbacks
from JSS.env.JSS import JSS
from ray.rllib.agents.ppo import ppo, PPOTrainer

from ray.tune.logger import DEFAULT_LOGGERS
from ray.tune.integration.wandb import WandbLogger

from JSS.env_wrapper import BestActionsWrapper

from JSS.models import FCMaskedActionsModel

pio.orca.config.use_xvfb = True
import wandb
import torch

'''
            'lr': {
                'values': [5e-5, 1e-5]
            },
            'lambda': {
                'values': [0.90, 0.95, 1.0]
            },
            'clip_param': {
                'values': [0.2, 0.3, 0.4]
            },
            'num_sgd_iter': {
                'values': [30, 35, 40]
            },
            'entropy_coeff': {
                'values': [0.0, 1e-4]
            }
'''

if __name__ == "__main__":
    print("I have detected {} CPUs here, so I'm going to create {} actors".format(mp.cpu_count(), mp.cpu_count() - 1))
    os.environ["WANDB_API_KEY"] = '3487a01956bf67cc7882bca2a38f70c8c95f8463'
    sweep_config = {
        'program': 'train.py',
        'method': 'grid',
        'metric': {
            'name': 'time_step_min',
            'goal': 'minimize',
        },
        'parameters': {
            'instance_path': {
                'values': ['/JSS/JSS/env/instances/ta51', '/JSS/JSS/env/instances/ta52', '/JSS/JSS/env/instances/ta53', '/JSS/JSS/env/instances/ta54', '/JSS/JSS/env/instances/ta55',
                           '/JSS/JSS/env/instances/ta56', '/JSS/JSS/env/instances/ta57', '/JSS/JSS/env/instances/ta58', '/JSS/JSS/env/instances/ta59',
                           '/JSS/JSS/env/instances/ta60']
            }
        }
    }
# Out:
# I have detected 80 CPUs here, so I'm going to create 79 actors

# %%
sweep_id = wandb.sweep(sweep_config, project="RLLIB_SWEEP_4")
# Out:
# Create sweep with ID: 2rk3apl0
# Sweep URL: https://wandb.ai/ingambe/RLLIB_SWEEP_4/sweeps/2rk3apl0

# %%
# !wandb agent 2rk3apl0
# Out:
# wandb: Starting wandb agent 🕵️
# 2020-11-13 15:44:42,612 - wandb.wandb_agent - INFO - Running runs: []
# 2020-11-13 15:44:42,954 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-11-13 15:44:42,954 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta51
# 2020-11-13 15:44:42,956 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --instance_path=/JSS/JSS/env/instances/ta51
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.10.10
# wandb: Syncing run rural-sweep-1
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_4
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_4/sweeps/2rk3apl0
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_4/runs/tdepb25x
# wandb: Run data is saved locally in /JSS/JSS/wandb/run-20201113_154444-tdepb25x
# wandb: Run `wandb off` to turn off syncing.
#
# 2020-11-13 15:44:47,971 - wandb.wandb_agent - INFO - Running runs: ['tdepb25x']
# 2020-11-13 15:44:48,035	INFO services.py:1090 -- View the Ray dashboard at http://127.0.0.1:8265
# == Status ==
# Memory usage on this node: 17.0/754.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 80/80 CPUs, 1/3 GPUs, 0.0/558.06 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /root/ray_results/ppo-jss
# Number of trials: 1/1 (1 RUNNING)
# +-------------------------+----------+-------+
# | Trial name              | status   | loc   |
# |-------------------------+----------+-------|
# | PPO_jss_env_c897a_00000 | RUNNING  |       |
# +-------------------------+----------+-------+
#
#
# (pid=44156) 2020-11-13 15:44:51,979	INFO trainer.py:617 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=44113) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44113)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44109) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44109)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44153) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44153)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44141) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44141)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44143) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44143)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44154) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44154)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44138) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44138)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44151) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44151)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44119) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44119)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44121) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44121)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44122) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44122)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44115) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44115)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44097) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44097)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44094) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44094)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44132) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44132)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44127) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44127)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44150) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44150)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44062) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44062)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44148) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44148)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44077) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44077)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44081) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44081)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44130) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44130)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44056) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44056)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44069) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44069)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44075) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44075)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44070) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44070)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44078) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44078)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44100) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44100)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44125) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44125)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44096) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44096)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44145) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44145)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44092) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44092)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44082) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44082)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44133) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44133)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44098) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44098)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44101) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44101)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44064) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44064)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44089) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44089)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44103) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44103)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44021) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44021)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44074) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44074)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44025) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44025)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44039) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44039)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44031) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44031)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44059) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44059)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44093) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44093)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44076) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44076)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44036) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44036)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44104) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44104)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44026) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44026)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44023) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44023)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44040) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44040)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44024) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44024)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44086) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44086)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44080) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44080)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44057) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44057)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44022) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44022)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44019) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44019)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44032) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44032)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44030) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44030)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44027) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44027)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44068) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44068)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44123) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44123)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44066) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44066)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44043) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44043)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44083) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44083)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44088) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44088)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44038) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44038)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44051) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44051)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44079) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44079)   tensor = torch.from_numpy(np.asarray(item))
# (pid=44071) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=44071)   tensor = torch.from_numpy(np.asarray(item))
# ...
# (pid=14172)   tensor = torch.from_numpy(np.asarray(item))
# (pid=14135) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=14135)   tensor = torch.from_numpy(np.asarray(item))
# (pid=14151) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=14151)   tensor = torch.from_numpy(np.asarray(item))
# (pid=14176) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=14176)   tensor = torch.from_numpy(np.asarray(item))
# (pid=14187) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1603729061180/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=14187)   tensor = torch.from_numpy(np.asarray(item))
# Result for PPO_jss_env_be844_00000:
#   custom_metrics:
#     time_step_max: 3669
#     time_step_mean: 3363.603448275862
#     time_step_min: 3125
#   date: 2020-11-13_16-06-40
#   done: false
#   episode_len_mean: 881.5316455696203
#   episode_reward_max: 283.8080808080806
#   episode_reward_mean: 244.05069684183616
#   episode_reward_min: 164.4141414141411
#   episodes_this_iter: 158
#   episodes_total: 158
#   experiment_id: dcc88113fcfd4d659700d89b6d0bf564
#   experiment_tag: '0'
#   hostname: f85e62b52919
#   info:
#     learner:
#       default_policy:
#         allreduce_latency: 0.0
#         cur_kl_coeff: 0.20000000000000004
#         cur_lr: 5.0e-05
#         entropy: 1.1715543866157532
#         entropy_coeff: 0.0005000000000000001
#         kl: 0.00394408325276648
#         model: {}
#         policy_loss: -0.007785314014957597
#         total_loss: 516.1754811604818
#         vf_explained_var: 0.48966696858406067
#         vf_loss: 516.1830622355143
#     num_steps_sampled: 161792
#     num_steps_trained: 161792
#   iterations_since_restore: 1
#   node_ip: 172.17.0.14
#   num_healthy_workers: 79
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 30.886111111111113
#     gpu_util_percent0: 0.2511111111111111
#     gpu_util_percent1: 0.0
#     gpu_util_percent2: 0.7450000000000001
#     ram_util_percent: 4.316666666666666
#     vram_util_percent0: 0.08761069203017381
#     vram_util_percent1: 0.0
#     vram_util_percent2: 0.9949178691351303
#   pid: 14213
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.17069182082361997
#     mean_env_wait_ms: 1.1491829953689787
#     mean_inference_ms: 6.437734131019547
#     mean_raw_obs_processing_ms: 0.46933520388625294
#   time_since_restore: 29.765793561935425
#   time_this_iter_s: 29.765793561935425
#   time_total_s: 29.765793561935425
#   timers:
#     learn_throughput: 8303.607
#     learn_time_ms: 19484.544
#     sample_throughput: 15837.342
#     sample_time_ms: 10215.856
#     update_time_ms: 32.938
#   timestamp: 1605280000
#   timesteps_since_restore: 0
#   timesteps_total: 161792
#   training_iteration: 1
#   trial_id: be844_00000
#
# == Status ==
# Memory usage on this node: 33.4/754.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 80/80 CPUs, 1/3 GPUs, 0.0/558.01 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /root/ray_results/ppo-jss
# Number of trials: 1/1 (1 RUNNING)
# +-------------------------+----------+-------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name              | status   | loc               |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-------------------------+----------+-------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | PPO_jss_env_be844_00000 | RUNNING  | 172.17.0.14:14213 |      1 |          29.7658 | 161792 |  244.051 |              283.808 |              164.414 |            881.532 |
# +-------------------------+----------+-------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# Result for PPO_jss_env_be844_00000:
#   custom_metrics:
#     time_step_max: 3887
#     time_step_mean: 3383.4598540145985
#     time_step_min: 3125
#   date: 2020-11-13_16-07-08
#   done: false
#   episode_len_mean: 881.2373417721519
#   episode_reward_max: 283.8080808080806
#   episode_reward_mean: 241.74920086945414
#   episode_reward_min: 164.4141414141411
#   episodes_this_iter: 158
#   episodes_total: 316
#   experiment_id: dcc88113fcfd4d659700d89b6d0bf564
#   experiment_tag: '0'
#   hostname: f85e62b52919
#   info:
#     learner:
#       default_policy:
#         allreduce_latency: 0.0
#         cur_kl_coeff: 0.10000000000000002
#         cur_lr: 5.0e-05
#         entropy: 1.1413444181283314
#         entropy_coeff: 0.0005000000000000001
#         kl: 0.007237302178206543
#         model: {}
#         policy_loss: -0.008619486619863892
#         total_loss: 138.6196492513021
#         vf_explained_var: 0.7862326502799988
#         vf_loss: 138.62811660766602
#     num_steps_sampled: 323584
#     num_steps_trained: 323584
#   iterations_since_restore: 2
#   node_ip: 172.17.0.14
#   num_healthy_workers: 79
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 27.318181818181813
#     gpu_util_percent0: 0.3054545454545455
#     gpu_util_percent1: 0.0
#     gpu_util_percent2: 0.8975757575757576
#     ram_util_percent: 4.542424242424242
#     vram_util_percent0: 0.10749426041325025
#     vram_util_percent1: 0.0
#     vram_util_percent2: 0.9949178691351304
#   pid: 14213
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.16700294004995186
#     mean_env_wait_ms: 1.1441726760130417
#     mean_inference_ms: 6.062729440884565
#     mean_raw_obs_processing_ms: 0.454724498730335
#   time_since_restore: 57.07484984397888
#   time_this_iter_s: 27.309056282043457
#   time_total_s: 57.07484984397888
#   timers:
#     learn_throughput: 8380.159
#     learn_time_ms: 19306.554
#     sample_throughput: 17658.451
#     sample_time_ms: 9162.298
#     update_time_ms: 26.92
#   timestamp: 1605280028
#   timesteps_since_restore: 0
#   timesteps_total: 323584
#   training_iteration: 2
#   trial_id: be844_00000
#
# == Status ==
# Memory usage on this node: 34.0/754.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 80/80 CPUs, 1/3 GPUs, 0.0/558.01 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /root/ray_results/ppo-jss
# Number of trials: 1/1 (1 RUNNING)
# +-------------------------+----------+-------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name              | status   | loc               |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-------------------------+----------+-------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | PPO_jss_env_be844_00000 | RUNNING  | 172.17.0.14:14213 |      2 |          57.0748 | 323584 |  241.749 |              283.808 |              164.414 |            881.237 |
# +-------------------------+----------+-------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# Result for PPO_jss_env_be844_00000:
#   custom_metrics:
#     time_step_max: 3887
#     time_step_mean: 3389.472222222222
#     time_step_min: 3125
#   date: 2020-11-13_16-07-35
#   done: false
#   episode_len_mean: 875.8354430379746
#   episode_reward_max: 283.8080808080806
#   episode_reward_mean: 241.80514000767175
#   episode_reward_min: 164.4141414141411
#   episodes_this_iter: 158
#   episodes_total: 474
#   experiment_id: dcc88113fcfd4d659700d89b6d0bf564
#   experiment_tag: '0'
#   hostname: f85e62b52919
#   info:
#     learner:
#       default_policy:
#         allreduce_latency: 0.0
#         cur_kl_coeff: 0.10000000000000002
#         cur_lr: 5.0e-05
#         entropy: 1.1273849407831829
#         entropy_coeff: 0.0005000000000000001
#         kl: 0.0100278170624127
#         model: {}
#         policy_loss: -0.012776134710293263
#         total_loss: 56.055432637532554
#         vf_explained_var: 0.8890635967254639
#         vf_loss: 56.06777127583822
#     num_steps_sampled: 485376
#     num_steps_trained: 485376
#   iterations_since_restore: 3
#   node_ip: 172.17.0.14
#   num_healthy_workers: 79
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 26.424242424242426
#     gpu_util_percent0: 0.26878787878787874
#     gpu_util_percent1: 0.0
#     gpu_util_percent2: 0.8978787878787878
#     ram_util_percent: 4.557575757575758
#     vram_util_percent0: 0.10749426041325025
#     vram_util_percent1: 0.0
#     vram_util_percent2: 0.9949178691351304
#   pid: 14213
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.1646005657474401
#     mean_env_wait_ms: 1.1426141677440527
#     mean_inference_ms: 5.809013339159433
#     mean_raw_obs_processing_ms: 0.4450430515663428
#   time_since_restore: 84.04224634170532
#   time_this_iter_s: 26.96739649772644
#   time_total_s: 84.04224634170532
#   timers:
#     learn_throughput: 8396.236
#     learn_time_ms: 19269.586
#     sample_throughput: 18657.125
#     sample_time_ms: 8671.861
#     update_time_ms: 25.71
#   timestamp: 1605280055
#   timesteps_since_restore: 0
#   timesteps_total: 485376
#   training_iteration: 3
#   trial_id: be844_00000
#
# == Status ==
# Memory usage on this node: 33.8/754.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 80/80 CPUs, 1/3 GPUs, 0.0/558.01 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /root/ray_results/ppo-jss
# Number of trials: 1/1 (1 RUNNING)
# +-------------------------+----------+-------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name              | status   | loc               |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-------------------------+----------+-------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | PPO_jss_env_be844_00000 | RUNNING  | 172.17.0.14:14213 |      3 |          84.0422 | 485376 |  241.805 |              283.808 |              164.414 |            875.835 |
# +-------------------------+----------+-------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# Result for PPO_jss_env_be844_00000:
#   custom_metrics:
#     time_step_max: 3887
#     time_step_mean: 3384.905084745763
#     time_step_min: 3073
#   date: 2020-11-13_16-08-02
#   done: false
#   episode_len_mean: 871.1629746835443
#   episode_reward_max: 289.5656565656569
#   episode_reward_mean: 241.86571410305595
#   episode_reward_min: 164.4141414141411
#   episodes_this_iter: 158
#   episodes_total: 632
#   experiment_id: dcc88113fcfd4d659700d89b6d0bf564
#   experiment_tag: '0'
#   hostname: f85e62b52919
#   info:
#     learner:
#       default_policy:
#         allreduce_latency: 0.0
#         cur_kl_coeff: 0.10000000000000002
#         cur_lr: 5.0e-05
#         entropy: 1.1123367249965668
#         entropy_coeff: 0.0005000000000000001
#         kl: 0.008589126247291764
#         model: {}
#         policy_loss: -0.01170988604038333
#         total_loss: 45.69587484995524
#         vf_explained_var: 0.9131764769554138
#         vf_loss: 45.70728079477946
#     num_steps_sampled: 647168
#     num_steps_trained: 647168
#   iterations_since_restore: 4
#   node_ip: 172.17.0.14
#   num_healthy_workers: 79
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 26.254545454545454
#     gpu_util_percent0: 0.36363636363636365
#     gpu_util_percent1: 0.0
#     gpu_util_percent2: 0.9018181818181819
#     ram_util_percent: 4.5606060606060606
#     vram_util_percent0: 0.10749426041325025
#     vram_util_percent1: 0.0
#     vram_util_percent2: 0.9949178691351304
#   pid: 14213
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.16287073731544346
#     mean_env_wait_ms: 1.1426755431155544
#     mean_inference_ms: 5.630816383098376
#     mean_raw_obs_processing_ms: 0.43763058341130745
#   time_since_restore: 110.91626715660095
#   time_this_iter_s: 26.87402081489563
#   time_total_s: 110.91626715660095
#   timers:
#     learn_throughput: 8424.026
#     learn_time_ms: 19206.019
#     sample_throughput: 19179.186
#     sample_time_ms: 8435.811
#     update_time_ms: 38.522
#   timestamp: 1605280082
#   timesteps_since_restore: 0
#   timesteps_total: 647168
#   training_iteration: 4
#   trial_id: be844_00000
#
# == Status ==
# Memory usage on this node: 34.0/754.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 80/80 CPUs, 1/3 GPUs, 0.0/558.01 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /root/ray_results/ppo-jss
# Number of trials: 1/1 (1 RUNNING)
# +-------------------------+----------+-------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name              | status   | loc               |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-------------------------+----------+-------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | PPO_jss_env_be844_00000 | RUNNING  | 172.17.0.14:14213 |      4 |          110.916 | 647168 |  241.866 |              289.566 |              164.414 |            871.163 |
# +-------------------------+----------+-------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
