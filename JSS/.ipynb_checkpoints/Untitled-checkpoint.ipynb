# %%
import os
import multiprocessing as mp
import plotly.io as pio
import ray
from ray import tune

from JSS.CustomCallbacks import CustomCallbacks
from JSS.env.JSS import JSS
from ray.rllib.agents.ppo import ppo, PPOTrainer

from ray.tune.logger import DEFAULT_LOGGERS
from ray.tune.integration.wandb import WandbLogger

from JSS.env_wrapper import BestActionsWrapper

from JSS.models import FCMaskedActionsModel

pio.orca.config.use_xvfb = True
import wandb

'''
            'lr': {
                'values': [5e-5, 1e-5]
            },
            'lambda': {
                'values': [0.90, 0.95, 1.0]
            },
            'clip_param': {
                'values': [0.2, 0.3, 0.4]
            },
            'num_sgd_iter': {
                'values': [30, 35, 40]
            },
            'entropy_coeff': {
                'values': [0.0, 1e-4]
            }
'''

if __name__ == "__main__":
    print("I have detected {} CPUs here, so I'm going to create {} actors".format(mp.cpu_count(), mp.cpu_count() - 1))
    os.environ["WANDB_API_KEY"] = '3487a01956bf67cc7882bca2a38f70c8c95f8463'
    sweep_config = {
        'program': 'RandomGreedy.py',
        'method': 'grid',
        'metric': {
            'name': 'time_step_min',
            'goal': 'minimize',
        },
        'parameters': {
            'instance_path': {
                'values': ['/JSS/JSS/env/instances/ta51', '/JSS/JSS/env/instances/ta52', '/JSS/JSS/env/instances/ta53', '/JSS/JSS/env/instances/ta54',
                           '/JSS/JSS/env/instances/ta55', '/JSS/JSS/env/instances/ta56', '/JSS/JSS/env/instances/ta57', '/JSS/JSS/env/instances/ta58',
                           '/JSS/JSS/env/instances/ta59', '/JSS/JSS/env/instances/ta60']
            }
        }
    }
# Out:
# I have detected 80 CPUs here, so I'm going to create 79 actors

# %%
sweep_id = wandb.sweep(sweep_config, project="RLLIB_SWEEP_2")
# Out:
# Create sweep with ID: u34ll0uk
# Sweep URL: https://wandb.ai/ingambe/RLLIB_SWEEP_2/sweeps/u34ll0uk

# %%
# !wandb agent u34ll0uk
# Out:
# wandb: Starting wandb agent 🕵️
# 2020-10-12 14:18:04,700 - wandb.wandb_agent - INFO - Running runs: []
# 2020-10-12 14:18:05,135 - wandb.wandb_agent - INFO - Agent received command: run
# 2020-10-12 14:18:05,136 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	instance_path: /JSS/JSS/env/instances/ta51
# 2020-10-12 14:18:05,137 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --instance_path=/JSS/JSS/env/instances/ta51
# wandb: Currently logged in as: ingambe (use `wandb login --relogin` to force relogin)
# 2020-10-12 14:18:10,153 - wandb.wandb_agent - INFO - Running runs: ['ghl8l9jj']
# wandb: Tracking run with wandb version 0.10.5
# wandb: Syncing run trim-sweep-1
# wandb: ⭐️ View project at https://wandb.ai/ingambe/RLLIB_SWEEP_2
# wandb: 🧹 View sweep at https://wandb.ai/ingambe/RLLIB_SWEEP_2/sweeps/u34ll0uk
# wandb: 🚀 View run at https://wandb.ai/ingambe/RLLIB_SWEEP_2/runs/ghl8l9jj
# wandb: Run data is saved locally in wandb/run-20201012_141806-ghl8l9jj
# wandb: Run `wandb off` to turn off syncing.
#
# 2020-10-12 14:18:10,755	INFO services.py:1164 -- View the Ray dashboard at http://127.0.0.1:8265
# == Status ==
# Memory usage on this node: 11.5/754.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 80/80 CPUs, 1/3 GPUs, 0.0/557.57 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /root/ray_results/ppo-jss
# Number of trials: 1 (1 RUNNING)
# +-------------------------+----------+-------+
# | Trial name              | status   | loc   |
# |-------------------------+----------+-------|
# | PPO_jss_env_c29f8_00000 | RUNNING  |       |
# +-------------------------+----------+-------+
#
#
# (pid=70054) 2020-10-12 14:18:13,502	INFO trainer.py:616 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=70052) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70052)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70034) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70034)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70041) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70041)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70019) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70019)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70045) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70045)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70044) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70044)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70068) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70068)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70070) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70070)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70077) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70077)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70017) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70017)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70032) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70032)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70020) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70020)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70033) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70033)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70035) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70035)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70042) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70042)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70055) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70055)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70046) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70046)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70025) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70025)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70084) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70084)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70076) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70076)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70048) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70048)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70030) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70030)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69979) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69979)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69958) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69958)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69945) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69945)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70016) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70016)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70026) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70026)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70027) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70027)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70028) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70028)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69959) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69959)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69962) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69962)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70057) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70057)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69946) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69946)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69963) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69963)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69987) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69987)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70023) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70023)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69953) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69953)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69950) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69950)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70060) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70060)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70009) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70009)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69981) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69981)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69965) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69965)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69986) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69986)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69947) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69947)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70056) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70056)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70082) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70082)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70018) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70018)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70010) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70010)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69972) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69972)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69968) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69968)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69984) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69984)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69966) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69966)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69967) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69967)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70051) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70051)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69956) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69956)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69949) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69949)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70059) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70059)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70021) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70021)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70066) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70066)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70011) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70011)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70072) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70072)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69955) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69955)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70007) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70007)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70064) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70064)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69975) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69975)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69961) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69961)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69951) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69951)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70014) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70014)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70015) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70015)   tensor = torch.from_numpy(np.asarray(item))
# (pid=70024) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=70024)   tensor = torch.from_numpy(np.asarray(item))
# (pid=69954) /root/miniconda3/lib/python3.8/site-packages/ray/rllib/utils/torch_ops.py:65: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629401015/work/torch/csrc/utils/tensor_numpy.cpp:141.)
# (pid=69954)   tensor = torch.from_numpy(np.asarray(item))
# ...
#   custom_metrics:
#     time_step_max: 4054
#     time_step_mean: 3601.8677130044844
#     time_step_min: 3250
#   date: 2020-10-12_14-19-39
#   done: false
#   episode_len_mean: 885.132911392405
#   episode_reward_max: 273.5959595959592
#   episode_reward_mean: 219.87009333844756
#   episode_reward_min: 145.7171717171716
#   episodes_this_iter: 158
#   episodes_total: 474
#   experiment_id: 824facd13c99490c857fa26d81a874e0
#   experiment_tag: '0'
#   hostname: f85e62b52919
#   info:
#     learner:
#       default_policy:
#         allreduce_latency: 0.0
#         cur_kl_coeff: 0.10000000000000002
#         cur_lr: 5.0e-05
#         entropy: 1.1456398169199626
#         entropy_coeff: 0.0005000000000000001
#         kl: 0.008224547879459957
#         model: {}
#         policy_loss: -0.013529085864623388
#         total_loss: 61.275455474853516
#         vf_explained_var: 0.8916645646095276
#         vf_loss: 61.28873507181803
#     num_steps_sampled: 485376
#     num_steps_trained: 485376
#   iterations_since_restore: 3
#   node_ip: 172.17.0.4
#   num_healthy_workers: 79
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 24.036666666666665
#     gpu_util_percent0: 0.4583333333333333
#     gpu_util_percent1: 0.0
#     gpu_util_percent2: 0.0
#     ram_util_percent: 3.766666666666666
#     vram_util_percent0: 0.10437848474909811
#     vram_util_percent1: 0.0
#     vram_util_percent2: 0.0
#   pid: 70054
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.16292763164001656
#     mean_env_wait_ms: 1.1660419208572714
#     mean_inference_ms: 5.433839896911039
#     mean_raw_obs_processing_ms: 0.4330986534385022
#   time_since_restore: 80.38152575492859
#   time_this_iter_s: 26.184955596923828
#   time_total_s: 80.38152575492859
#   timers:
#     learn_throughput: 8760.554
#     learn_time_ms: 18468.239
#     sample_throughput: 19699.668
#     sample_time_ms: 8212.93
#     update_time_ms: 40.926
#   timestamp: 1602512379
#   timesteps_since_restore: 0
#   timesteps_total: 485376
#   training_iteration: 3
#   trial_id: c29f8_00000
#
# == Status ==
# Memory usage on this node: 28.0/754.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 80/80 CPUs, 1/3 GPUs, 0.0/557.57 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /root/ray_results/ppo-jss
# Number of trials: 1 (1 RUNNING)
# +-------------------------+----------+------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name              | status   | loc              |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-------------------------+----------+------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | PPO_jss_env_c29f8_00000 | RUNNING  | 172.17.0.4:70054 |      3 |          80.3815 | 485376 |   219.87 |              273.596 |              145.717 |            885.133 |
# +-------------------------+----------+------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# Result for PPO_jss_env_c29f8_00000:
#   custom_metrics:
#     time_step_max: 4054
#     time_step_mean: 3596.0099337748343
#     time_step_min: 3231
#   date: 2020-10-12_14-20-04
#   done: false
#   episode_len_mean: 878.7689873417721
#   episode_reward_max: 276.47474747474763
#   episode_reward_mean: 220.6047340493541
#   episode_reward_min: 145.7171717171716
#   episodes_this_iter: 158
#   episodes_total: 632
#   experiment_id: 824facd13c99490c857fa26d81a874e0
#   experiment_tag: '0'
#   hostname: f85e62b52919
#   info:
#     learner:
#       default_policy:
#         allreduce_latency: 0.0
#         cur_kl_coeff: 0.10000000000000002
#         cur_lr: 5.0e-05
#         entropy: 1.1263898611068726
#         entropy_coeff: 0.0005000000000000001
#         kl: 0.008100568510902425
#         model: {}
#         policy_loss: -0.013406771836647144
#         total_loss: 47.16934140523275
#         vf_explained_var: 0.9198758602142334
#         vf_loss: 47.18250052134196
#     num_steps_sampled: 647168
#     num_steps_trained: 647168
#   iterations_since_restore: 4
#   node_ip: 172.17.0.4
#   num_healthy_workers: 79
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 25.53103448275862
#     gpu_util_percent0: 0.2900000000000001
#     gpu_util_percent1: 0.0
#     gpu_util_percent2: 0.0
#     ram_util_percent: 3.768965517241379
#     vram_util_percent0: 0.10437848474909811
#     vram_util_percent1: 0.0
#     vram_util_percent2: 0.0
#   pid: 70054
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.16094661920745734
#     mean_env_wait_ms: 1.167455903288604
#     mean_inference_ms: 5.2910087094709635
#     mean_raw_obs_processing_ms: 0.42653092723086955
#   time_since_restore: 105.78936982154846
#   time_this_iter_s: 25.407844066619873
#   time_total_s: 105.78936982154846
#   timers:
#     learn_throughput: 8772.696
#     learn_time_ms: 18442.677
#     sample_throughput: 20485.045
#     sample_time_ms: 7898.054
#     update_time_ms: 40.294
#   timestamp: 1602512404
#   timesteps_since_restore: 0
#   timesteps_total: 647168
#   training_iteration: 4
#   trial_id: c29f8_00000
#
# == Status ==
# Memory usage on this node: 28.2/754.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 80/80 CPUs, 1/3 GPUs, 0.0/557.57 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /root/ray_results/ppo-jss
# Number of trials: 1 (1 RUNNING)
# +-------------------------+----------+------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name              | status   | loc              |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-------------------------+----------+------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | PPO_jss_env_c29f8_00000 | RUNNING  | 172.17.0.4:70054 |      4 |          105.789 | 647168 |  220.605 |              276.475 |              145.717 |            878.769 |
# +-------------------------+----------+------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# Result for PPO_jss_env_c29f8_00000:
#   custom_metrics:
#     time_step_max: 4054
#     time_step_mean: 3581.6985583224114
#     time_step_min: 3204
#   date: 2020-10-12_14-20-30
#   done: false
#   episode_len_mean: 872.4867256637168
#   episode_reward_max: 280.5656565656565
#   episode_reward_mean: 222.48133675567283
#   episode_reward_min: 145.7171717171716
#   episodes_this_iter: 159
#   episodes_total: 791
#   experiment_id: 824facd13c99490c857fa26d81a874e0
#   experiment_tag: '0'
#   hostname: f85e62b52919
#   info:
#     learner:
#       default_policy:
#         allreduce_latency: 0.0
#         cur_kl_coeff: 0.10000000000000002
#         cur_lr: 5.0e-05
#         entropy: 1.0873714486757915
#         entropy_coeff: 0.0005000000000000001
#         kl: 0.006956188706681132
#         model: {}
#         policy_loss: -0.011262792395427823
#         total_loss: 34.19948164621989
#         vf_explained_var: 0.9459590911865234
#         vf_loss: 34.2105925877889
#     num_steps_sampled: 808960
#     num_steps_trained: 808960
#   iterations_since_restore: 5
#   node_ip: 172.17.0.4
#   num_healthy_workers: 79
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 24.066666666666663
#     gpu_util_percent0: 0.43766666666666665
#     gpu_util_percent1: 0.0
#     gpu_util_percent2: 0.0
#     ram_util_percent: 3.7666666666666657
#     vram_util_percent0: 0.10437848474909811
#     vram_util_percent1: 0.0
#     vram_util_percent2: 0.0
#   pid: 70054
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.15940651242537818
#     mean_env_wait_ms: 1.169971635752512
#     mean_inference_ms: 5.180106083655211
#     mean_raw_obs_processing_ms: 0.4212780660858121
#   time_since_restore: 131.2926995754242
#   time_this_iter_s: 25.503329753875732
#   time_total_s: 131.2926995754242
#   timers:
#     learn_throughput: 8760.483
#     learn_time_ms: 18468.388
#     sample_throughput: 21079.592
#     sample_time_ms: 7675.291
#     update_time_ms: 36.471
#   timestamp: 1602512430
#   timesteps_since_restore: 0
#   timesteps_total: 808960
#   training_iteration: 5
#   trial_id: c29f8_00000
#
# == Status ==
# Memory usage on this node: 28.2/754.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 80/80 CPUs, 1/3 GPUs, 0.0/557.57 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /root/ray_results/ppo-jss
# Number of trials: 1 (1 RUNNING)
# +-------------------------+----------+------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name              | status   | loc              |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-------------------------+----------+------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | PPO_jss_env_c29f8_00000 | RUNNING  | 172.17.0.4:70054 |      5 |          131.293 | 808960 |  222.481 |              280.566 |              145.717 |            872.487 |
# +-------------------------+----------+------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# Result for PPO_jss_env_c29f8_00000:
#   custom_metrics:
#     time_step_max: 4054
#     time_step_mean: 3564.887755102041
#     time_step_min: 3204
#   date: 2020-10-12_14-20-56
#   done: false
#   episode_len_mean: 860.6943942133815
#   episode_reward_max: 280.5656565656565
#   episode_reward_mean: 225.7112809834327
#   episode_reward_min: 145.7171717171716
#   episodes_this_iter: 315
#   episodes_total: 1106
#   experiment_id: 824facd13c99490c857fa26d81a874e0
#   experiment_tag: '0'
#   hostname: f85e62b52919
#   info:
#     learner:
#       default_policy:
#         allreduce_latency: 0.0
#         cur_kl_coeff: 0.10000000000000002
#         cur_lr: 5.0e-05
#         entropy: 1.0886386533578236
#         entropy_coeff: 0.0005000000000000001
#         kl: 0.007588425030310948
#         model: {}
#         policy_loss: -0.01092883839737624
#         total_loss: 30.730765342712402
#         vf_explained_var: 0.9611188769340515
#         vf_loss: 30.741480032602947
#     num_steps_sampled: 970752
#     num_steps_trained: 970752
#   iterations_since_restore: 6
#   node_ip: 172.17.0.4
#   num_healthy_workers: 79
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 25.18965517241379
#     gpu_util_percent0: 0.2837931034482758
#     gpu_util_percent1: 0.0
#     gpu_util_percent2: 0.0
#     ram_util_percent: 3.7620689655172406
#     vram_util_percent0: 0.10437848474909811
#     vram_util_percent1: 0.0
#     vram_util_percent2: 0.0
#   pid: 70054
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.15734562235197594
#     mean_env_wait_ms: 1.1756497799942263
#     mean_inference_ms: 5.0326967604555675
#     mean_raw_obs_processing_ms: 0.41464838863890185
#   time_since_restore: 156.71548414230347
#   time_this_iter_s: 25.422784566879272
#   time_total_s: 156.71548414230347
#   timers:
#     learn_throughput: 8759.305
#     learn_time_ms: 18470.871
#     sample_throughput: 21462.045
#     sample_time_ms: 7538.517
#     update_time_ms: 36.673
#   timestamp: 1602512456
#   timesteps_since_restore: 0
#   timesteps_total: 970752
#   training_iteration: 6
#   trial_id: c29f8_00000
#
# == Status ==
# Memory usage on this node: 28.2/754.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 80/80 CPUs, 1/3 GPUs, 0.0/557.57 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /root/ray_results/ppo-jss
# Number of trials: 1 (1 RUNNING)
# +-------------------------+----------+------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
# | Trial name              | status   | loc              |   iter |   total time (s) |     ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-------------------------+----------+------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------|
# | PPO_jss_env_c29f8_00000 | RUNNING  | 172.17.0.4:70054 |      6 |          156.715 | 970752 |  225.711 |              280.566 |              145.717 |            860.694 |
# +-------------------------+----------+------------------+--------+------------------+--------+----------+----------------------+----------------------+--------------------+
#
#
# Result for PPO_jss_env_c29f8_00000:
#   custom_metrics:
#     time_step_max: 4054
#     time_step_mean: 3552.704692556634
#     time_step_min: 3179
#   date: 2020-10-12_14-21-21
#   done: false
#   episode_len_mean: 855.0387658227849
#   episode_reward_max: 284.35353535353545
#   episode_reward_mean: 227.46978487405684
#   episode_reward_min: 145.7171717171716
#   episodes_this_iter: 158
#   episodes_total: 1264
#   experiment_id: 824facd13c99490c857fa26d81a874e0
#   experiment_tag: '0'
#   hostname: f85e62b52919
#   info:
#     learner:
#       default_policy:
#         allreduce_latency: 0.0
#         cur_kl_coeff: 0.10000000000000002
#         cur_lr: 5.0e-05
#         entropy: 1.0706470410029094
#         entropy_coeff: 0.0005000000000000001
#         kl: 0.007387861027382314
#         model: {}
#         policy_loss: -0.013462736414415607
#         total_loss: 19.742233912150066
#         vf_explained_var: 0.9632093906402588
#         vf_loss: 19.75549300511678
#     num_steps_sampled: 1132544
#     num_steps_trained: 1132544
#   iterations_since_restore: 7
#   node_ip: 172.17.0.4
#   num_healthy_workers: 79
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 25.182758620689658
#     gpu_util_percent0: 0.30241379310344835
#     gpu_util_percent1: 0.0
#     gpu_util_percent2: 0.0
#     ram_util_percent: 3.775862068965517
#     vram_util_percent0: 0.10437848474909811
#     vram_util_percent1: 0.0
#     vram_util_percent2: 0.0
#   pid: 70054
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.15659944710447274
#     mean_env_wait_ms: 1.1781296386862312
#     mean_inference_ms: 4.979102261022608
#     mean_raw_obs_processing_ms: 0.41223103840983283
#   time_since_restore: 182.10720825195312
#   time_this_iter_s: 25.391724109649658
#   time_total_s: 182.10720825195312
#   timers:
#     learn_throughput: 8762.399
#     learn_time_ms: 18464.35
#     sample_throughput: 21732.82
#     sample_time_ms: 7444.593
#     update_time_ms: 36.744
#   timestamp: 1602512481
#   timesteps_since_restore: 0
#   timesteps_total: 1132544
#   training_iteration: 7
#   trial_id: c29f8_00000
#
# == Status ==
# Memory usage on this node: 28.1/754.6 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 80/80 CPUs, 1/3 GPUs, 0.0/557.57 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:RTX)
# Result logdir: /root/ray_results/ppo-jss
# Number of trials: 1 (1 RUNNING)
# +-------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
# | Trial name              | status   | loc              |   iter |   total time (s) |      ts |   reward |   episode_reward_max |   episode_reward_min |   episode_len_mean |
# |-------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------|
# | PPO_jss_env_c29f8_00000 | RUNNING  | 172.17.0.4:70054 |      7 |          182.107 | 1132544 |   227.47 |              284.354 |              145.717 |            855.039 |
# +-------------------------+----------+------------------+--------+------------------+---------+----------+----------------------+----------------------+--------------------+
